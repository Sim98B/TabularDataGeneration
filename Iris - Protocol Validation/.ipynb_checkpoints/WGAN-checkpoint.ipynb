# %% [markdown]
# # Iris Data Generation

# %% [markdown]
# # Index
#
# 1. [Libraries](#Libraries)
# 2. [Data Preparation](#Getting-Started)
# 3. [Exploring Architectures](#GAN-vs-VAE)
# 4. [Optimizing Architecture](#Conditional-Generative-Adversarial-Network)
# 5. [Another perspective: Wasserstein Conditional Generative Adversarial Network](#Introducing-the-WGAN)
# 6. [Final Evaluation](#Evaluating-Synthetic-Data)

# %% [markdown]
# ## Libraries

# %%
import sys
import os

import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import skew, kurtosis, iqr

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import torchmetrics

import random
from tqdm.auto import tqdm

# %%
project_path = os.path.abspath("..")

if project_path not in sys.path:
    sys.path.append(project_path)

import utils

# %% [markdown]
# ## Getting Started
# The iris dataset will be used to validate the tabular data generation protocol, which despite its apparent simplicity may harbor pitfalls.

# %%
X, y = load_iris()['data'], load_iris()['target']
features, species = load_iris()['feature_names'], load_iris()['target_names']

real_iris = pd.DataFrame(X, columns = features)
real_iris['target'] = y
real_iris['target'] = real_iris['target'].map({i: species[i] for i in range(len(species))})
real_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# Let's deep dive into our real data.

# %%
utils.describe_data(real_iris, 'target')
# Out:
#                          REAL
#                        setosa versicolor virginica
# MEAN sepal length (cm)  5.006      5.936     6.588
#      sepal width (cm)   3.428      2.770     2.974
#      petal length (cm)  1.462      4.260     5.552
#      petal width (cm)   0.246      1.326     2.026
# STD  sepal length (cm)  0.352      0.516     0.636
#      sepal width (cm)   0.379      0.314     0.322
#      petal length (cm)  0.174      0.470     0.552
#      petal width (cm)   0.105      0.198     0.275
# MIN  sepal length (cm)  4.300      4.900     4.900
#      sepal width (cm)   2.300      2.000     2.200
#      petal length (cm)  1.000      3.000     4.500
#      petal width (cm)   0.100      1.000     1.400
# MAX  sepal length (cm)  5.800      7.000     7.900
#      sepal width (cm)   4.400      3.400     3.800
#      petal length (cm)  1.900      5.100     6.900
#      petal width (cm)   0.600      1.800     2.500
# SKEW sepal length (cm)  0.116      0.102     0.114
#      sepal width (cm)   0.040     -0.352     0.355
#      petal length (cm)  0.103     -0.588     0.533
#      petal width (cm)   1.216     -0.030    -0.126
# KURT sepal length (cm) -0.346     -0.599    -0.088
#      sepal width (cm)   0.744     -0.448     0.520
#      petal length (cm)  0.805     -0.074    -0.256
#      petal width (cm)   1.434     -0.488    -0.661
# IQR  sepal length (cm)  0.400      0.700     0.675
#      sepal width (cm)   0.475      0.475     0.375
#      petal length (cm)  0.175      0.600     0.775
#      petal width (cm)   0.100      0.300     0.500

# %%
utils.plot_data(real_iris, 'target')

# %% [markdown]
# Throughout the notebook we will make comparisons between two datasets, one real and one synthetic; the following dataset, generated by adding normal noise to the real one, is used to introduce the comparison functions.

# %%
df = real_iris.select_dtypes('number') + np.random.normal(0, 1, (150,4))
df['target'] = real_iris['target']
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0           4.274502          4.257453           2.526960          0.015566
# 1           6.253404          4.972593           2.034256          1.871097
# 2           4.806414          3.086299           2.641531         -0.355388
# 3           4.615350          3.223307           0.498680         -0.578105
# 4           4.426288          3.698776           0.968472          0.438703
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# Let's start with comparisons!
#
# First of all a simply comparison between descriptives.

# %%
utils.describe_data(real_iris, 'target', df).style.background_gradient('Reds', axis = 1)
# Out:
# <style type="text/css">
# #T_d8946_row0_col0, #T_d8946_row1_col1, #T_d8946_row2_col0, #T_d8946_row3_col0, #T_d8946_row4_col0, #T_d8946_row5_col1, #T_d8946_row6_col0, #T_d8946_row7_col0, #T_d8946_row8_col3, #T_d8946_row9_col3, #T_d8946_row10_col3, #T_d8946_row11_col3, #T_d8946_row12_col0, #T_d8946_row13_col1, #T_d8946_row14_col0, #T_d8946_row15_col0, #T_d8946_row16_col4, #T_d8946_row17_col1, #T_d8946_row18_col1, #T_d8946_row19_col2, #T_d8946_row20_col1, #T_d8946_row20_col4, #T_d8946_row21_col1, #T_d8946_row22_col5, #T_d8946_row23_col2, #T_d8946_row24_col0, #T_d8946_row25_col2, #T_d8946_row26_col0, #T_d8946_row27_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_d8946_row0_col1 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_d8946_row0_col2 {
#   background-color: #8e0912;
#   color: #f1f1f1;
# }
# #T_d8946_row0_col3, #T_d8946_row21_col4 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_d8946_row0_col4 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_d8946_row0_col5, #T_d8946_row1_col0, #T_d8946_row2_col5, #T_d8946_row3_col5, #T_d8946_row4_col5, #T_d8946_row5_col4, #T_d8946_row6_col5, #T_d8946_row7_col3, #T_d8946_row8_col1, #T_d8946_row8_col2, #T_d8946_row9_col0, #T_d8946_row10_col2, #T_d8946_row11_col2, #T_d8946_row12_col5, #T_d8946_row13_col3, #T_d8946_row14_col5, #T_d8946_row15_col5, #T_d8946_row16_col3, #T_d8946_row17_col4, #T_d8946_row18_col2, #T_d8946_row19_col0, #T_d8946_row20_col5, #T_d8946_row21_col0, #T_d8946_row22_col0, #T_d8946_row23_col0, #T_d8946_row24_col4, #T_d8946_row25_col4, #T_d8946_row26_col5, #T_d8946_row27_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d8946_row1_col2, #T_d8946_row22_col2 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_d8946_row1_col3 {
#   background-color: #c3161b;
#   color: #f1f1f1;
# }
# #T_d8946_row1_col4 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_d8946_row1_col5 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_d8946_row2_col1 {
#   background-color: #e02c26;
#   color: #f1f1f1;
# }
# #T_d8946_row2_col2, #T_d8946_row7_col5 {
#   background-color: #6b010e;
#   color: #f1f1f1;
# }
# #T_d8946_row2_col3 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_d8946_row2_col4 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_d8946_row3_col1 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_d8946_row3_col2 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_d8946_row3_col3 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_d8946_row3_col4, #T_d8946_row12_col3 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_d8946_row4_col1 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_d8946_row4_col2, #T_d8946_row11_col4 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_d8946_row4_col3 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_d8946_row4_col4 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_d8946_row5_col0 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_d8946_row5_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_d8946_row5_col3 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_d8946_row5_col5, #T_d8946_row24_col3 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# #T_d8946_row6_col1 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_d8946_row6_col2 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_d8946_row6_col3 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_d8946_row6_col4 {
#   background-color: #e12d26;
#   color: #f1f1f1;
# }
# #T_d8946_row7_col1, #T_d8946_row25_col0, #T_d8946_row25_col1 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_d8946_row7_col2, #T_d8946_row23_col5 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_d8946_row7_col4 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_d8946_row8_col0, #T_d8946_row10_col5 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_d8946_row8_col4, #T_d8946_row26_col1 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_d8946_row8_col5 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_d8946_row9_col1 {
#   background-color: #b71319;
#   color: #f1f1f1;
# }
# #T_d8946_row9_col2 {
#   background-color: #840711;
#   color: #f1f1f1;
# }
# #T_d8946_row9_col4 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_d8946_row9_col5 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_d8946_row10_col0 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_d8946_row10_col1 {
#   background-color: #d01d1f;
#   color: #f1f1f1;
# }
# #T_d8946_row10_col4, #T_d8946_row11_col5, #T_d8946_row16_col1 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_d8946_row11_col0 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_d8946_row11_col1, #T_d8946_row27_col3 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
# }
# #T_d8946_row12_col1 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_d8946_row12_col2, #T_d8946_row15_col2 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_d8946_row12_col4 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_d8946_row13_col0 {
#   background-color: #fc8969;
#   color: #f1f1f1;
# }
# #T_d8946_row13_col2 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_d8946_row13_col4 {
#   background-color: #ab1016;
#   color: #f1f1f1;
# }
# #T_d8946_row13_col5 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_d8946_row14_col1, #T_d8946_row17_col3 {
#   background-color: #fa6849;
#   color: #f1f1f1;
# }
# #T_d8946_row14_col2 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_d8946_row14_col3 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_d8946_row14_col4 {
#   background-color: #ce1a1e;
#   color: #f1f1f1;
# }
# #T_d8946_row15_col1 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_d8946_row15_col3, #T_d8946_row18_col5 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_d8946_row15_col4 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_d8946_row16_col0 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_d8946_row16_col2 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_d8946_row16_col5 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_d8946_row17_col0, #T_d8946_row22_col3 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_d8946_row17_col2, #T_d8946_row22_col4 {
#   background-color: #ad1117;
#   color: #f1f1f1;
# }
# #T_d8946_row17_col5 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_d8946_row18_col0 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_d8946_row18_col3 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_d8946_row18_col4 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_d8946_row19_col1, #T_d8946_row19_col5 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_d8946_row19_col3 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_d8946_row19_col4 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_d8946_row20_col0 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_d8946_row20_col2 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_d8946_row20_col3 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_d8946_row21_col2 {
#   background-color: #b81419;
#   color: #f1f1f1;
# }
# #T_d8946_row21_col3 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_d8946_row21_col5 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_d8946_row22_col1, #T_d8946_row23_col4 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_d8946_row23_col1 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_d8946_row23_col3 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_d8946_row24_col1 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_d8946_row24_col2 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_d8946_row24_col5 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_d8946_row25_col3 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_d8946_row25_col5 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_d8946_row26_col2 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_d8946_row26_col3 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_d8946_row26_col4 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_d8946_row27_col1 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_d8946_row27_col2 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_d8946_row27_col4 {
#   backg

# %%
utils.plot_data(real_iris, 'target', df)

# %% [markdown]
# Throughout the work, the goal will be to minimize the differences, numerical and graphical, between the actual and synthetic data. Two different architectures will be used to achieve this goal: the Variational Auto Encoder **(VAE)** and the Generative Adversarial Network **(GAN)**, and the one that will show the best performance for the same task complexity and resources will be selected.

# %% [markdown]
# ## GAN vs VAE

# %% [markdown]
# Both valid, the two approaches show different challenges and advantages:
#
# 1. **Variational Auto Encoder**:
#
# Pros:
# - Easy to train
# - We can look inside the neaural network "Black Box"
#
# Cons:
#
# - Less coverage of variability
# - Assumption of data normality
#
# 2. **Generative Adversarial Network**:
#
# Pros:
# - More realistic generated data
# - Flexibility with respect to actual data distributions
#
# Cons:
# - Hard to train (model collapse, lot of resources, lot of data)
# - Lower interpretability
#
# The performance of the two architectures will be analyzed using them in as simple a version as possible. The next step will then be to prepare the data for modeling.

# %%
std_scl = StandardScaler()
X_scld = std_scl.fit_transform(X)

ohe = OneHotEncoder(sparse_output = False)
y_ohe = ohe.fit_transform(y.reshape(-1,1))

# %% [markdown]
# Preparing Torch Dataset and Dataloader.

# %%
class IrisDataset(Dataset):
    def __init__(self, data, target):
        self.data = torch.tensor(data, dtype = torch.float32)
        self.label = torch.tensor(target, dtype = torch.long)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.label[idx]
    
real_vae_dataset = IrisDataset(X_scld, y_ohe)
real_vae_dataloader = DataLoader(real_vae_dataset, batch_size = 32, shuffle = True)

real_gan_dataset = IrisDataset(X_scld, y)
real_gan_dataloader = DataLoader(real_gan_dataset, batch_size = 32, shuffle = True)

for dataloader in [real_vae_dataloader, real_gan_dataloader]:
    for batch in dataloader:
        print(f'Data shape: {batch[0].shape}, labels shape: {batch[1].shape}')
        break
# Out:
# Data shape: torch.Size([32, 4]), labels shape: torch.Size([32, 3])
# Data shape: torch.Size([32, 4]), labels shape: torch.Size([32])

# %% [markdown]
# Let's build baseline models, starting with the Conditional VAE.

# %%
class ConditionalVAE(nn.Module):
    def __init__(self, input_dim, latent_dim, condition_dim):
        super(ConditionalVAE, self).__init__()
        self.latent_dim = latent_dim
        
        self.encoder = nn.Sequential(
            nn.Linear(input_dim + condition_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
        )
        
        self.fc_mu = nn.Linear(16, latent_dim)
        self.fc_logvar = nn.Linear(16, latent_dim)
        
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim + condition_dim, 16),
            nn.ReLU(),
            nn.Linear(16, 32),
            nn.ReLU(),
            nn.Linear(32, input_dim),
            nn.Tanh()
        )
        
    def encode(self, x, c):
        x_cond = torch.cat([x, c], dim=1)
        h = self.encoder(x_cond)
        mu = self.fc_mu(h)
        logvar = self.fc_logvar(h)
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z, c):
        z_cond = torch.cat([z, c], dim=1)
        return self.decoder(z_cond)

    def forward(self, x, c):
        mu, logvar = self.encode(x, c)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decode(z, c)
        return recon_x, mu, logvar
    
utils.set_seed()
vae = ConditionalVAE(input_dim = 4, latent_dim = 4, condition_dim = 3)

for batch in real_vae_dataloader:
    vae_batch = batch
    break
    
vae_out = vae(vae_batch[0], vae_batch[1])
for out in vae_out:
    print(f'Shape: {out.shape}')
# Out:
# Shape: torch.Size([32, 4])
# Shape: torch.Size([32, 4])
# Shape: torch.Size([32, 4])

# %% [markdown]
# Now let's build the GAN's nets.

# %%
class Generator(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        self.label_emb = nn.Embedding(num_classes, num_classes)
        
        self.model = nn.Sequential(
            nn.Linear(input_dim + num_classes, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 4),
        )
        
    def forward(self, x, labels):
        label_embeddings = self.label_emb(labels)
        x = torch.cat([x, label_embeddings], dim = 1)
        x = self.model(x)
        return x
    
class Discriminator(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
            
        self.label_emb = nn.Embedding(num_classes, num_classes)
        
        self.model = nn.Sequential(
            nn.Linear(input_dim + num_classes, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )
        
    def forward(self, x, labels):
        label_embeddings = self.label_emb(labels)
        x = torch.cat([x, label_embeddings], dim = 1)
        x = self.model(x)
        return x

utils.set_seed()    
gen = Generator(input_dim = 4, num_classes = 3)
disc = Discriminator(input_dim = 4, num_classes = 3)

for batch in real_gan_dataloader:
    gan_batch = batch
    break
    
print(f'Generator output shape: {gen(torch.randn(32, 4), gan_batch[1]).shape}')
print(f'Discriminator output shape: {disc(gan_batch[0], gan_batch[1]).shape}')
# Out:
# Generator output shape: torch.Size([32, 4])
# Discriminator output shape: torch.Size([32, 1])

# %% [markdown]
# Let's check models' size in parameters.

# %%
print(f'VAE has {sum(p.numel() for p in vae.parameters())/1000} k parameters')
print(f'Gen has {sum(p.numel() for p in gen.parameters())/1000} k parameters')
print(f'Disc has {sum(p.numel() for p in disc.parameters())/1000} k parameters')
# Out:
# VAE has 1.724 k parameters
# Gen has 0.861 k parameters
# Disc has 0.81 k parameters

# %% [markdown]
# Models have approximately the same number of parameters.
#
# We can now train the simpliest Conditional VAE.

# %%
vae_opt = torch.optim.Adam(vae.parameters(), lr = 1e-3)

def vae_loss(reconstructed, original, mu, logvar, beta=1.0):
    recon_loss = F.mse_loss(reconstructed, original, reduction='mean')
    
    kl_div = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    kl_div /= original.size(0)

    total_loss = recon_loss + beta * kl_div
    return total_loss, recon_loss, kl_div

utils.set_seed()
z = torch.randn(150, 4)

# %%
for epoch in tqdm(range(1, 501), desc = 'Training VAE'):
    
    vae.train()
    epoch_loss = 0
    
    for data, label in real_vae_dataloader:
        
        reconstructed, mu, logvar = vae(data, label)
        loss, recon_loss, kl_div = vae_loss(reconstructed, data, mu, logvar)
        
        vae_opt.zero_grad()
        loss.backward()
        vae_opt.step()
        
        epoch_loss += loss.item()
        
    epoch_total_loss = epoch_loss/len(real_vae_dataloader)
    
    if epoch % 100 == 0 or epoch == 50:
        
        print(f'\nEpoch {epoch}/500 | Loss: {epoch_total_loss:.4f}')
        with torch.no_grad():
            vae.eval()
            vae_z = vae(z, real_vae_dataloader.dataset.label)[0]
            utils.compare_results(real_vae_dataloader.dataset.data, vae_z)
# Out:
# Training VAE:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 50/500 | Loss: 0.3227
# MEAN: [-0.017  0.008 -0.08  -0.051]
# STD:  [0.283 0.434 0.225 0.253]
# MIN:  [-0.897 -1.855 -0.581 -0.465]
# MAX:  [1.615 2.23  0.845 0.815]
# SKEW: [ 0.647 -0.348  0.128  0.281]
# KURT: [0.931 1.651 0.12  0.177]
#
# Epoch 100/500 | Loss: 0.2992
# MEAN: [-0.002  0.003 -0.072 -0.032]
# STD:  [0.233 0.374 0.194 0.207]
# MIN:  [-0.886 -1.741 -0.572 -0.453]
# MAX:  [1.535 2.182 0.8   0.733]
# SKEW: [ 0.473 -0.185  0.048  0.104]
# KURT: [0.938 1.675 0.115 0.176]
#
# Epoch 200/500 | Loss: 0.2913
# MEAN: [-0.01  -0.001 -0.09  -0.051]
# STD:  [0.224 0.368 0.182 0.19 ]
# MIN:  [-0.877 -1.709 -0.568 -0.448]
# MAX:  [1.538 2.174 0.797 0.722]
# SKEW: [ 0.505 -0.103  0.089  0.129]
# KURT: [0.929 1.672 0.111 0.171]
#
# Epoch 300/500 | Loss: 0.2944
# MEAN: [-0.013 -0.007 -0.089 -0.05 ]
# STD:  [0.219 0.364 0.179 0.185]
# MIN:  [-0.877 -1.717 -0.568 -0.448]
# MAX:  [1.541 2.193 0.793 0.718]
# SKEW: [ 0.499 -0.089  0.064  0.1  ]
# KURT: [0.928 1.676 0.107 0.168]
#
# Epoch 400/500 | Loss: 0.2872
# MEAN: [-0.005 -0.006 -0.088 -0.052]
# STD:  [0.222 0.362 0.178 0.183]
# MIN:  [-0.874 -1.736 -0.568 -0.447]
# MAX:  [1.558 2.195 0.793 0.716]
# SKEW: [ 0.488 -0.128  0.058  0.1  ]
# KURT: [0.928 1.68  0.108 0.169]
#
# Epoch 500/500 | Loss: 0.2995
# MEAN: [-0.009  0.    -0.088 -0.048]
# STD:  [0.22  0.373 0.177 0.183]
# MIN:  [-0.876 -1.728 -0.568 -0.447]
# MAX:  [1.56  2.216 0.791 0.715]
# SKEW: [ 0.502 -0.106  0.051  0.083]
# KURT: [0.928 1.678 0.108 0.169]

# %%
vae_df = pd.DataFrame(std_scl.inverse_transform(vae_z.detach().numpy()))
vae_df['target'] = y
vae_df['target'] = vae_df['target'].map({i: species[i] for i in range(len(species))})
vae_df.columns = real_iris.columns

# %% [markdown]
# Let's train the Conditional GAN.

# %%
g_opt = torch.optim.Adam(gen.parameters(), lr = 1e-3)
d_opt = torch.optim.Adam(disc.parameters(), lr = 1e-3)

criterion = nn.BCELoss()

utils.set_seed()
z = torch.randn(150, 4)

# %%
for epoch in tqdm(range(501), desc = 'Training Conditional GAN'):
    
    gen_epoch_loss = 0
    disc_epoch_loss = 0
    
    disc.train()
    gen.train()
    
    for data, labels in real_gan_dataloader:
        
        real_data = data
        real_labels = torch.ones(real_data.shape[0], 1)
        
        train_z = torch.randn(real_data.shape[0], 4)
        fake_data = gen(train_z, labels)
        fake_labels = torch.zeros(real_data.shape[0], 1)
        
        disc.zero_grad()
        
        real_loss = criterion(disc(real_data, labels), real_labels)
        fake_loss = criterion(disc(fake_data.detach(), labels), fake_labels)
        d_loss = (real_loss + fake_loss) / 2
        disc_epoch_loss += d_loss.item()
        d_loss.backward()
        
        d_opt.step()
        
        gen.zero_grad()
        
        gen_labels = torch.ones(real_data.shape[0], 1)
        
        g_loss = criterion(disc(fake_data, labels), gen_labels)
        gen_epoch_loss += g_loss.item()
        g_loss.backward()
        
        g_opt.step()
        
    g_epoch_loss = gen_epoch_loss/len(real_gan_dataloader)
    d_epoch_loss = disc_epoch_loss/len(real_gan_dataloader)
    
    if epoch % 100 == 0 or epoch == 500:
        
        print(f'\nEpoch {epoch}/500 | DLoss: {d_epoch_loss:.4f} | GLoss {g_epoch_loss:.4f}')
        with torch.no_grad():
            gen.eval()
            gen_z = gen(z, real_gan_dataloader.dataset.label)
            utils.compare_results(real_gan_dataloader.dataset.data, gen_z)
# Out:
# Training Conditional GAN:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 0/500 | DLoss: 0.7049 | GLoss 0.8255
# MEAN: [ 0.033 -0.012 -0.096 -0.011]
# STD:  [0.965 0.964 0.969 0.935]
# MIN:  [-1.721 -2.333 -1.584 -1.283]
# MAX:  [2.438 2.961 1.563 1.514]
# SKEW: [ 0.531 -0.075 -0.764 -0.276]
# KURT: [-0.946 -0.561 -2.841 -0.99 ]
#
# Epoch 100/500 | DLoss: 0.6766 | GLoss 0.7381
# MEAN: [ 1.178  0.847  0.444 -0.09 ]
# STD:  [0.281 0.398 0.118 0.102]
# MIN:  [ 1.076 -0.597  0.278 -0.11 ]
# MAX:  [2.856 2.985 0.897 0.211]
# SKEW: [ 0.985 -0.152  0.035  0.228]
# KURT: [0.48  1.558 0.045 0.088]
#
# Epoch 200/500 | DLoss: 0.7312 | GLoss 0.6434
# MEAN: [ 0.032 -0.386 -0.037 -0.121]
# STD:  [ 0.147  0.315  0.119 -0.063]
# MIN:  [-0.763 -1.7   -0.207 -0.03 ]
# MAX:  [ 1.062  1.716  0.37  -0.073]
# SKEW: [-0.217  0.858 -0.129 -0.168]
# KURT: [0.87  1.638 0.069 0.152]
#
# Epoch 300/500 | DLoss: 0.6807 | GLoss 0.7064
# MEAN: [ 0.41  -0.046 -0.049 -0.151]
# STD:  [0.234 0.235 0.136 0.043]
# MIN:  [-0.19  -1.107 -0.176 -0.094]
# MAX:  [1.713 1.681 0.518 0.068]
# SKEW: [ 0.584 -0.189  0.305  0.292]
# KURT: [0.878 1.544 0.07  0.131]
#
# Epoch 400/500 | DLoss: 0.7205 | GLoss 0.7458
# MEAN: [-0.026  0.618 -0.132  0.396]
# STD:  [ 0.157 -0.026 -0.374 -0.3  ]
# MIN:  [-0.636  0.034  0.27   0.85 ]
# MAX:  [ 1.121  2.191 -0.337  0.203]
# SKEW: [ 0.52   0.137 -0.223 -0.256]
# KURT: [0.894 1.606 0.079 0.145]
#
# Epoch 500/500 | DLoss: 0.6592 | GLoss 0.7652
# MEAN: [-0.262 -0.268 -0.035 -0.094]
# STD:  [ 0.17   0.269 -0.321 -0.124]
# MIN:  [-0.901 -1.602  0.591  0.386]
# MAX:  [0.554 1.324 0.069 0.074]
# SKEW: [ 0.578 -0.32   0.329  0.476]
# KURT: [0.709 1.381 0.048 0.094]

# %%
gan_df = pd.DataFrame(std_scl.inverse_transform(gen_z.detach().numpy()))
gan_df['target'] = y
gan_df['target'] = gan_df['target'].map({i: species[i] for i in range(len(species))})
gan_df.columns = real_iris.columns

# %% [markdown]
# Let's check which of the two results better approximates the actual data using the Kolmogorov-Smirnov test and the Wasserstein Distance.

# %%
print(f"KS test for VAE Data:\n{round(utils.calculate_ks_test(real_iris, vae_df), 5)}\n")
print(f"KS test for GAN Data:\n{round(utils.calculate_ks_test(real_iris, gan_df), 5)}\n")

print(f"WD for VAE Data:\n{round(utils.calculate_wasserstein_distance(real_iris, vae_df), 5)}\n")
print(f"WD for GAN Data:\n{round(utils.calculate_wasserstein_distance(real_iris, gan_df), 5)}")
# Out:
# KS test for VAE Data:
#              Feature  KS Statistic  P-Value
# 0  sepal length (cm)       0.21333  0.00211
# 1   sepal width (cm)       0.28000  0.00001
# 2  petal length (cm)       0.33333  0.00000
# 3   petal width (cm)       0.32000  0.00000
#
# KS test for GAN Data:
#              Feature  KS Statistic  P-Value
# 0  sepal length (cm)       0.28667  0.00001
# 1   sepal width (cm)       0.29333  0.00000
# 2  petal length (cm)       0.33333  0.00000
# 3   petal width (cm)       0.32000  0.00000
#
# WD for VAE Data:
#              Feature  W Distance
# 0  sepal length (cm)     0.25957
# 1   sepal width (cm)     0.15692
# 2  petal length (cm)     0.41564
# 3   petal width (cm)     0.17683
#
# WD for GAN Data:
#              Feature  W Distance
# 0  sepal length (cm)     0.29182
# 1   sepal width (cm)     0.15968
# 2  petal length (cm)     0.63601
# 3   petal width (cm)     0.20348

# %% [markdown]
# As much as all the distances found using the KS test are significant (we have to reject H0 and so the distributions are not from the same population) these appear to be smaller overall for the VAE data. Even when examining Wasserstein's distances, the VAE seems to track the original distributions better. Let's check the Q-Q plots.

# %%
utils.plot_quantiles(real_iris, vae_df)
utils.plot_quantiles(real_iris, gan_df)

# %% [markdown]
# Examining the Q-Q plots there is slightly more overlap for the GAN-generated data. We will examine the data visually to make the final decision.

# %%
utils.plot_data(real_iris, 'target', vae_df)

# %%
utils.plot_data(real_iris, 'target', gan_df)

# %% [markdown]
# As much as it can still be improved GAN seems to be the most suitable architecture for replicating data so the focus of the next steps will be on finding the best architecture.

# %% [markdown]
# ## Conditional Generative Adversarial Network

# %% [markdown]
# In this section, we focus on refining the GAN architecture to maximize its performance in generating synthetic data that closely resembles the real dataset. Our aim is to improve the overlap between the distributions of generated and real data while maintaining computational efficiency. The resulting model will form the basis for subsequent evaluations and applications.
#
# The strating point is a model with 861 parameters. We'll build other 2 bigger versions to prove out which is the best; grid search will also take place on the optimal size of the noise vector for which we will explore the following sizes: 2, 4, 8, 16, 32, and 64.

# %%
# Smallest GAN

class Generator1(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        self.label_emb = nn.Embedding(num_classes, num_classes)
        
        self.model = nn.Sequential(
            nn.Linear(input_dim + num_classes, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 4),
        )
        
    def forward(self, x, labels):
        label_embeddings = self.label_emb(labels)
        x = torch.cat([x, label_embeddings], dim = 1)
        x = self.model(x)
        return x
    
class Discriminator1(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
            
        self.label_emb = nn.Embedding(num_classes, num_classes)
        
        self.model = nn.Sequential(
            nn.Linear(input_dim + num_classes, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )
        
    def forward(self, x, labels):
        label_embeddings = self.label_emb(labels)
        x = torch.cat([x, label_embeddings], dim = 1)
        x = self.model(x)
        return x

# Medium GAN

class Generator2(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        self.label_emb = nn.Embedding(num_classes, num_classes)
        
        self.model = nn.Sequential(
            nn.Linear(input_dim + num_classes, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 4),
        )
        
    def forward(self, x, labels):
        label_embeddings = self.label_emb(labels)
        x = torch.cat([x, label_embeddings], dim = 1)
        x = self.model(x)
        return x
    
class Discriminator2(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
            
        self.label_emb = nn.Embedding(num_classes, num_classes)
        
        self.model = nn.Sequential(
            nn.Linear(input_dim + num_classes, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )
        
    def forward(self, x, labels):
        label_embeddings = self.label_emb(labels)
        x = torch.cat([x, label_embeddings], dim = 1)
        x = self.model(x)
        return x

# Big GAN

class Generator3(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        self.label_emb = nn.Embedding(num_classes, num_classes)
        
        self.model = nn.Sequential(
            nn.Linear(input_dim + num_classes, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 4),
        )
        
    def forward(self, x, labels):
        label_embeddings = self.label_emb(labels)
        x = torch.cat([x, label_embeddings], dim = 1)
        x = self.model(x)
        return x
    
class Discriminator3(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
            
        self.label_emb = nn.Embedding(num_classes, num_classes)
        
        self.model = nn.Sequential(
            nn.Linear(input_dim + num_classes, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )
        
    def forward(self, x, labels):
        label_embeddings = self.label_emb(labels)
        x = torch.cat([x, label_embeddings], dim = 1)
        x = self.model(x)
        return x

# %%
small_gan_dict = {'Generator': Generator1, 'Discriminator': Discriminator1, 
                  'Generator List': [], 'Noise Vector List': [], 'Model Size':[], 'Dataframes':[]}
med_gan_dict = {'Generator': Generator2, 'Discriminator': Discriminator2, 
                'Generator List': [], 'Noise Vector List': [], 'Model Size':[], 'Dataframes':[]}
big_gan_dict = {'Generator': Generator3, 'Discriminator': Discriminator3, 
                'Generator List': [], 'Noise Vector List': [], 'Model Size':[], 'Dataframes':[]}

noise_size = [2**n for n in range(1, 7)]

criterion = nn.BCELoss()


for model_idx, model in enumerate([small_gan_dict, med_gan_dict, big_gan_dict]):
    for size_idx, size in enumerate(noise_size):
        
        utils.set_seed()
        gen = model['Generator'](input_dim = size, num_classes = 3)
        disc = model['Discriminator'](input_dim = 4, num_classes = 3)
        
        g_opt = torch.optim.Adam(gen.parameters(), lr = 1e-3)
        d_opt = torch.optim.Adam(disc.parameters(), lr = 1e-3)
        
        model['Noise Vector List'].append(size)
        model['Model Size'].append(sum(p.numel() for p in gen.parameters()))
        
        utils.set_seed()
        z = torch.randn(150, size)
        
        for epoch in tqdm(range(501), desc = f'GAN {model_idx + 1} NV {size}'):
            
            gen_epoch_loss = 0
            disc_epoch_loss = 0
    
            disc.train()
            gen.train()
            
            for data, labels in real_gan_dataloader:
                
                real_data = data
                real_labels = torch.ones(real_data.shape[0], 1)
            
                train_z = torch.randn(real_data.shape[0], size)
                fake_data = gen(train_z, labels)
                fake_labels = torch.zeros(real_data.shape[0], 1)
            
                disc.zero_grad()
                
                real_loss = criterion(disc(real_data, labels), real_labels)
                fake_loss = criterion(disc(fake_data.detach(), labels), fake_labels)
                d_loss = (real_loss + fake_loss) / 2
                disc_epoch_loss += d_loss.item()
                d_loss.backward()
            
                d_opt.step()
            
                gen.zero_grad()
            
                gen_labels = torch.ones(real_data.shape[0], 1)
            
                g_loss = criterion(disc(fake_data, labels), gen_labels)
                gen_epoch_loss += g_loss.item()
                g_loss.backward()
            
                g_opt.step()
                
            g_epoch_loss = gen_epoch_loss/len(real_gan_dataloader)
            d_epoch_loss = disc_epoch_loss/len(real_gan_dataloader)
            
            if epoch == 500:
        
                print(f'\nEpoch {epoch}/500 | DLoss: {d_epoch_loss:.4f} | GLoss {g_epoch_loss:.4f}')
                with torch.no_grad():
                    gen.eval()
                    gen_z = gen(z, real_gan_dataloader.dataset.label)
                    utils.compare_results(real_gan_dataloader.dataset.data, gen_z)
                    
        model['Dataframes'].append(std_scl.inverse_transform(gen(z, real_gan_dataloader.dataset.label).detach().numpy()))
# Out:
# GAN 1 NV 2:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6209 | GLoss 0.9150
# MEAN: [ 0.111 -0.704 -0.03  -0.01 ]
# STD:  [ 0.018 -0.068  0.016 -0.189]
# MIN:  [ 0.275 -1.34  -0.094  0.29 ]
# MAX:  [ 0.722 -0.468  0.336  0.008]
# SKEW: [ 0.514 -0.068  0.262  0.4  ]
# KURT: [0.745 0.862 0.054 0.121]
# GAN 1 NV 4:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6592 | GLoss 0.7652
# MEAN: [-0.262 -0.268 -0.035 -0.094]
# STD:  [ 0.17   0.269 -0.321 -0.124]
# MIN:  [-0.901 -1.602  0.591  0.386]
# MAX:  [0.554 1.324 0.069 0.074]
# SKEW: [ 0.578 -0.32   0.329  0.476]
# KURT: [0.709 1.381 0.048 0.094]
# GAN 1 NV 8:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6970 | GLoss 0.6959
# MEAN: [-0.584  0.194  0.21   0.155]
# STD:  [ 0.458  0.105 -0.168  0.045]
# MIN:  [-1.57  -0.66   0.42   0.156]
# MAX:  [0.233 0.979 0.19  0.542]
# SKEW: [-0.078 -0.019 -0.031  0.124]
# KURT: [-0.119  0.795  0.048  0.123]
# GAN 1 NV 16:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.7018 | GLoss 0.6735
# MEAN: [0.032 0.235 0.099 0.005]
# STD:  [-0.01   0.029  0.032  0.193]
# MIN:  [ 0.139  0.199  0.136 -0.17 ]
# MAX:  [0.51  1.649 0.494 0.475]
# SKEW: [ 0.25   0.336 -0.006 -0.041]
# KURT: [0.725 1.051 0.078 0.14 ]
# GAN 1 NV 32:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6634 | GLoss 0.8109
# MEAN: [-0.332  0.344  0.054  0.304]
# STD:  [ 0.115  0.017  0.022 -0.102]
# MIN:  [-0.431  0.8   -0.04   0.638]
# MAX:  [ 0.18   0.997  0.316 -0.313]
# SKEW: [ 0.345  0.222  0.208 -0.257]
# KURT: [ 0.379  0.089  0.066 -0.055]
# GAN 1 NV 64:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6974 | GLoss 0.6930
# MEAN: [-0.203 -0.059 -0.021  0.121]
# STD:  [ 0.241  0.196 -0.015  0.054]
# MIN:  [-0.873 -0.904 -0.108  0.262]
# MAX:  [1.079 0.884 0.44  0.465]
# SKEW: [ 0.535 -0.048  0.182  0.077]
# KURT: [0.819 0.71  0.094 0.099]
# GAN 2 NV 2:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6829 | GLoss 0.7761
# MEAN: [-0.799 -0.774 -0.459 -0.205]
# STD:  [ 0.003  0.33  -0.304 -0.133]
# MIN:  [-1.373 -1.53  -0.193  0.045]
# MAX:  [-0.041  1.213 -0.599 -0.013]
# SKEW: [-0.016  0.653 -0.104  0.213]
# KURT: [0.915 1.005 0.083 0.134]
# GAN 2 NV 4:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6963 | GLoss 0.7200
# MEAN: [ 0.004  0.128 -0.187 -0.025]
# STD:  [-0.07   0.246  0.041 -0.014]
# MIN:  [ 0.079 -1.131 -0.382  0.091]
# MAX:  [-0.321  0.577 -0.193  0.04 ]
# SKEW: [ 0.074 -0.799 -0.054  0.108]
# KURT: [ 0.116 -1.072  0.017  0.087]
# GAN 2 NV 8:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.5497 | GLoss 0.8513
# MEAN: [-0.273 -0.618 -0.073 -0.067]
# STD:  [0.149 0.451 0.089 0.059]
# MIN:  [-0.425 -2.081 -0.128  0.083]
# MAX:  [0.357 1.299 0.349 0.104]
# SKEW: [0.139 0.397 0.011 0.03 ]
# KURT: [0.496 0.93  0.088 0.129]
# GAN 2 NV 16:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6488 | GLoss 0.7494
# MEAN: [0.002 0.123 0.148 0.003]
# STD:  [0.107 0.13  0.109 0.089]
# MIN:  [-0.327 -0.569  0.128 -0.089]
# MAX:  [0.663 0.792 0.869 0.337]
# SKEW: [0.357 0.006 0.218 0.277]
# KURT: [0.657 0.422 0.08  0.132]
# GAN 2 NV 32:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6152 | GLoss 0.8094
# MEAN: [-0.181  0.032 -0.049  0.13 ]
# STD:  [ 0.065  0.028 -0.049  0.118]
# MIN:  [-0.301 -0.588 -0.01   0.202]
# MAX:  [0.572 0.707 0.469 0.508]
# SKEW: [ 0.315 -0.335  0.241  0.233]
# KURT: [ 0.614  0.137  0.076 -0.014]
# GAN 2 NV 64:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6222 | GLoss 1.1875
# MEAN: [ 0.119 -0.083 -0.029  0.122]
# STD:  [0.123 0.135 0.047 0.133]
# MIN:  [-0.414 -0.875 -0.143 -0.073]
# MAX:  [0.948 1.65  0.294 0.525]
# SKEW: [0.239 0.29  0.221 0.169]
# KURT: [0.871 1.657 0.052 0.126]
# GAN 3 NV 2:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6680 | GLoss 0.8431
# MEAN: [ 0.365 -0.109  0.119 -0.056]
# STD:  [-0.015  0.632 -0.062 -0.182]
# MIN:  [ 0.412 -1.525  0.548  0.515]
# MAX:  [1.598 2.172 0.561 0.159]
# SKEW: [0.928 0.502 0.347 0.287]
# KURT: [0.841 0.57  0.021 0.137]
# GAN 3 NV 4:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.5840 | GLoss 0.9956
# MEAN: [ 0.014 -0.229 -0.007 -0.007]
# STD:  [-0.114  0.569 -0.168 -0.275]
# MIN:  [-0.239 -1.999  0.437  0.903]
# MAX:  [-0.153  1.863 -0.626 -0.262]
# SKEW: [ 0.122  0.078 -0.231 -0.144]
# KURT: [ 0.759  1.358 -0.061  0.11 ]
# GAN 3 NV 8:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6487 | GLoss 0.8209
# MEAN: [ 0.119 -0.883 -0.216 -0.55 ]
# STD:  [ 0.094 -0.071 -0.001 -0.079]
# MIN:  [-0.357 -1.515 -0.175 -0.22 ]
# MAX:  [ 0.514 -1.678 -0.117 -0.557]
# SKEW: [ 0.164 -0.541  0.054  0.292]
# KURT: [ 0.328 -0.389 -0.001  0.109]
# GAN 3 NV 16:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6455 | GLoss 0.8099
# MEAN: [0.126 0.074 0.045 0.052]
# STD:  [ 0.141 -0.113  0.106  0.042]
# MIN:  [-0.048  0.079 -0.078  0.054]
# MAX:  [0.801 1.192 0.551 0.306]
# SKEW: [0.158 0.554 0.287 0.31 ]
# KURT: [0.411 0.945 0.007 0.06 ]
# GAN 3 NV 32:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6830 | GLoss 0.7960
# MEAN: [-0.55  -0.739 -0.035 -0.233]
# STD:  [-0.103  0.014  0.042 -0.257]
# MIN:  [-0.462 -0.321 -0.232 -0.177]
# MAX:  [ 0.241  1.118  0.344 -0.619]
# SKEW: [ 0.498  1.313 -0.323 -0.339]
# KURT: [0.903 0.077 0.14  0.135]
# GAN 3 NV 64:   0%|          | 0/501 [00:00<?, ?it/s]
# Epoch 500/500 | DLoss: 0.6885 | GLoss 0.7017
# MEAN: [-0.147 -0.534  0.047  0.055]
# STD:  [ 0.269 -0.059 -0.016 -0.157]
# MIN:  [-0.928 -0.433  0.038  0.426]
# MAX:  [1.09  0.605 0.332 0.044]
# SKEW: [ 0.329 -0.052  0.024  0.102]
# KURT: [0.791 1.394 0.064 0.112]

# %% [markdown]
# Let's check models' size.

# %%
for model_idx, model in enumerate([small_gan_dict, med_gan_dict, big_gan_dict]):
    for idx, size in enumerate(model['Model Size']):
        print(f"GAN {model_idx + 1} NV {model['Noise Vector List'][idx]} -> {size/1000}k parameters")
# Out:
# GAN 1 NV 2 -> 0.797k parameters
# GAN 1 NV 4 -> 0.861k parameters
# GAN 1 NV 8 -> 0.989k parameters
# GAN 1 NV 16 -> 1.245k parameters
# GAN 1 NV 32 -> 1.757k parameters
# GAN 1 NV 64 -> 2.781k parameters
# GAN 2 NV 2 -> 3.069k parameters
# GAN 2 NV 4 -> 3.197k parameters
# GAN 2 NV 8 -> 3.453k parameters
# GAN 2 NV 16 -> 3.965k parameters
# GAN 2 NV 32 -> 4.989k parameters
# GAN 2 NV 64 -> 7.037k parameters
# GAN 3 NV 2 -> 11.709k parameters
# GAN 3 NV 4 -> 11.965k parameters
# GAN 3 NV 8 -> 12.477k parameters
# GAN 3 NV 16 -> 13.501k parameters
# GAN 3 NV 32 -> 15.549k parameters
# GAN 3 NV 64 -> 19.645k parameters

# %% [markdown]
# As the size of the noise vector changes, the dimensions, in terms of parameters of each architecture remain quite similar.

# %%
ks_results_df = []
for model_idx, model in enumerate([small_gan_dict, med_gan_dict, big_gan_dict]):
    for idx, size in enumerate(model['Dataframes']):
        ks_results = utils.calculate_ks_test(real_iris, pd.DataFrame(size))
        ks_statistics = ks_results['KS Statistic']
        ks_results_df.append({'Model': f"GAN {model_idx + 1} NV {model['Noise Vector List'][idx]}", **ks_statistics})
comaprisons_df = pd.DataFrame(ks_results_df).set_index('Model')
comaprisons_df.columns = real_iris.columns[:-1]
comaprisons_df['avg_ks'] = comaprisons_df.mean(1)
comaprisons_df.sort_values('avg_ks').style.background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_d67a0_row0_col0, #T_d67a0_row3_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_d67a0_row0_col1 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_d67a0_row0_col2, #T_d67a0_row6_col2, #T_d67a0_row8_col2 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_d67a0_row0_col3, #T_d67a0_row4_col3 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_d67a0_row0_col4, #T_d67a0_row2_col1, #T_d67a0_row5_col0, #T_d67a0_row5_col3, #T_d67a0_row9_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_d67a0_row1_col0 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_d67a0_row1_col1, #T_d67a0_row4_col2 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_d67a0_row1_col2 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_d67a0_row1_col3 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_d67a0_row1_col4 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_d67a0_row2_col0 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_d67a0_row2_col2 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_d67a0_row2_col3 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_d67a0_row2_col4 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_d67a0_row3_col1 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_d67a0_row3_col2, #T_d67a0_row10_col2 {
#   background-color: #fc9272;
#   color: #000000;
# }
# #T_d67a0_row3_col3 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_d67a0_row3_col4 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_d67a0_row4_col0, #T_d67a0_row11_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_d67a0_row4_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_d67a0_row4_col4, #T_d67a0_row5_col1 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_d67a0_row5_col2 {
#   background-color: #940b13;
#   color: #f1f1f1;
# }
# #T_d67a0_row5_col4 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_d67a0_row6_col0 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_d67a0_row6_col1, #T_d67a0_row7_col1, #T_d67a0_row10_col0 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_d67a0_row6_col3, #T_d67a0_row8_col3 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_d67a0_row6_col4 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_d67a0_row7_col0, #T_d67a0_row7_col2, #T_d67a0_row15_col0 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_d67a0_row7_col3 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_d67a0_row7_col4 {
#   background-color: #fc9576;
#   color: #000000;
# }
# #T_d67a0_row8_col0 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_d67a0_row8_col1 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_d67a0_row8_col4 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_d67a0_row9_col0 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_d67a0_row9_col1 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_d67a0_row9_col3, #T_d67a0_row13_col3 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_d67a0_row9_col4 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_d67a0_row10_col1 {
#   background-color: #e12d26;
#   color: #f1f1f1;
# }
# #T_d67a0_row10_col3, #T_d67a0_row10_col4 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_d67a0_row11_col0, #T_d67a0_row12_col1, #T_d67a0_row14_col2, #T_d67a0_row15_col3, #T_d67a0_row17_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d67a0_row11_col2, #T_d67a0_row13_col2 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_d67a0_row11_col3 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_d67a0_row11_col4 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_d67a0_row12_col0 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_d67a0_row12_col2 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_d67a0_row12_col3 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_d67a0_row12_col4 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_d67a0_row13_col0 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_d67a0_row13_col1 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_d67a0_row13_col4, #T_d67a0_row14_col4 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_d67a0_row14_col0, #T_d67a0_row14_col1 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_d67a0_row14_col3 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_d67a0_row15_col1 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_d67a0_row15_col2 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_d67a0_row15_col4 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_d67a0_row16_col0, #T_d67a0_row16_col2 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_d67a0_row16_col1 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
# }
# #T_d67a0_row16_col3, #T_d67a0_row17_col0 {
#   background-color: #e02c26;
#   color: #f1f1f1;
# }
# #T_d67a0_row16_col4, #T_d67a0_row17_col1 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_d67a0_row17_col2 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_d67a0_row17_col3 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d67a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d67a0_level0_col0" class="col_heading level0 col0" >sepal length (cm)</th>
#       <th id="T_d67a0_level0_col1" class="col_heading level0 col1" >sepal width (cm)</th>
#       <th id="T_d67a0_level0_col2" class="col_heading level0 col2" >petal length (cm)</th>
#       <th id="T_d67a0_level0_col3" class="col_heading level0 col3" >petal width (cm)</th>
#       <th id="T_d67a0_level0_col4" class="col_heading level0 col4" >avg_ks</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d67a0_level0_row0" class="row_heading level0 row0" >GAN 3 NV 16</th>
#       <td id="T_d67a0_row0_col0" class="data row0 col0" >0.100000</td>
#       <td id="T_d67a0_row0_col1" class="data row0 col1" >0.133333</td>
#       <td id="T_d67a0_row0_col2" class="data row0 col2" >0.146667</td>
#       <td id="T_d67a0_row0_col3" class="data row0 col3" >0.180000</td>
#       <td id="T_d67a0_row0_col4" class="data row0 col4" >0.140000</td>
#     </tr>
#     <tr>
#       <th id="T_d67a0_level0_row1" class="row_heading level0 row1" >GAN 2 NV 32</th>
#       <td id="T_d67a0_row1_col0" class="data row1 col0" >0.126667</td>
#       <td id="T_d67a0_row1_col1" class="data row1 col1" >0.146667</td>
#       <td id="T_d67a0_row1_col2" class="data row1 col2" >0.153333</td>
#       <td id="T_d67a0_row1_col3" class="data row1 col3" >0.166667</td>
#       <td id="T_d67a0_row1_col4" class="data row1 col4" >0.148333</td>
#     </tr>
#     <tr>
#       <th id="T_d67a0_level0_row2" class="row_heading level0 row2" >GAN 1 NV 64</th>
#       <td id="T_d67a0_row2_col0" class="data row2 col0" >0.226667</td>
#       <td id="T_d67a0_row2_col1" class="data row2 col1" >0.113333</td>
#       <td id="T_d67a0_row2_col2" class="data row2 col2" >0.133333</td>
#       <td id="T_d67a0_row2_col3" class="data row2 col3" >0.140000</td>
#       <td id="T_d67a0_row2_col4" class="data row2 col4" >0.153333</td>
#     </tr>
#     <tr>
#       <th id="T_d67a0_level0_row3" class="row_heading level0 row3" >GAN 2 NV 16</th>
#       <td id="T_d67a0_row3_col0" class="data row3 col0" >0.100000</td>
#       <td id="T_d67a0_row3_col1" class="data row3 col1" >0.153333</td>
#       <td id="T_d67a0_row3_col2" class="data row3 col2" >0.200000</td>
#       <td id="T_d67a0_row3_col3" class="data row3 col3" >0.200000</td>
#       <td id="T_d67a0_row3_col4" class="data row3 col4" >0.163333</td>
#     </tr>
#     <tr>
#       <th id="T_d67a0_level0_row4" class="row_heading level0 row4" >GAN 2 NV 64</th>
#       <td id="T_d67a0_row4_col0" class="data row4 col0" >0.173333</td>
#       <td id="T_d67a0_row4_col1" class="data row4 col1" >0.173333</td>
#       <td id="T_d67a0_row4_col2" class="data row4 col2" >0.140000</td>
#       <td id="T_d67a0_row4_col3" class="data row4 col3" >0.180000</td>
#       <td id="T_d67a0_row4_co

# %%
wd_results_df = []
for model_idx, model in enumerate([small_gan_dict, med_gan_dict, big_gan_dict]):
    for idx, size in enumerate(model['Dataframes']):
        wd_results = utils.calculate_wasserstein_distance(real_iris, pd.DataFrame(size))
        wd_statistics = wd_results['W Distance']
        wd_results_df.append({'Model': f"GAN {model_idx + 1} NV {model['Noise Vector List'][idx]}", **wd_statistics})
comaprisons_df = pd.DataFrame(wd_results_df).set_index('Model')
comaprisons_df.columns = real_iris.columns[:-1]
comaprisons_df['avg_wd'] = comaprisons_df.mean(1)
comaprisons_df.sort_values('avg_wd').style.background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_e521d_row0_col0, #T_e521d_row6_col3 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_e521d_row0_col1, #T_e521d_row2_col4, #T_e521d_row6_col2 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_e521d_row0_col2 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_e521d_row0_col3 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_e521d_row0_col4, #T_e521d_row2_col0, #T_e521d_row2_col3, #T_e521d_row4_col1, #T_e521d_row8_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_e521d_row1_col0 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_e521d_row1_col1 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_e521d_row1_col2 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_e521d_row1_col3, #T_e521d_row13_col3 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_e521d_row1_col4 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_e521d_row2_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_e521d_row2_col2 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_e521d_row3_col0, #T_e521d_row5_col0 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_e521d_row3_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_e521d_row3_col2, #T_e521d_row5_col1 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_e521d_row3_col3, #T_e521d_row4_col2 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_e521d_row3_col4 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_e521d_row4_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_e521d_row4_col3 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_e521d_row4_col4 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_e521d_row5_col2 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_e521d_row5_col3 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_e521d_row5_col4 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_e521d_row6_col0 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_e521d_row6_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_e521d_row6_col4 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_e521d_row7_col0 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_e521d_row7_col1 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_e521d_row7_col2, #T_e521d_row9_col3 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_e521d_row7_col3 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_e521d_row7_col4 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_e521d_row8_col0 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_e521d_row8_col1, #T_e521d_row11_col2 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_e521d_row8_col3, #T_e521d_row16_col3 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_e521d_row8_col4 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_e521d_row9_col0 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_e521d_row9_col1 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_e521d_row9_col2 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_e521d_row9_col4 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_e521d_row10_col0 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_e521d_row10_col1 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_e521d_row10_col2 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_e521d_row10_col3 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_e521d_row10_col4 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_e521d_row11_col0 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_e521d_row11_col1 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_e521d_row11_col3 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_e521d_row11_col4 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_e521d_row12_col0 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_e521d_row12_col1 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_e521d_row12_col2 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_e521d_row12_col3 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_e521d_row12_col4 {
#   background-color: #fc8060;
#   color: #f1f1f1;
# }
# #T_e521d_row13_col0 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_e521d_row13_col1 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_e521d_row13_col2 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_e521d_row13_col4 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_e521d_row14_col0, #T_e521d_row14_col3 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_e521d_row14_col1 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_e521d_row14_col2 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_e521d_row14_col4 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_e521d_row15_col0 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_e521d_row15_col1, #T_e521d_row15_col3, #T_e521d_row17_col0, #T_e521d_row17_col2, #T_e521d_row17_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e521d_row15_col2 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_e521d_row15_col4 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_e521d_row16_col0 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_e521d_row16_col1 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_e521d_row16_col2 {
#   background-color: #fc8d6d;
#   color: #f1f1f1;
# }
# #T_e521d_row16_col4 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_e521d_row17_col1 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_e521d_row17_col3 {
#   background-color: #fcae92;
#   color: #000000;
# }
# </style>
# <table id="T_e521d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e521d_level0_col0" class="col_heading level0 col0" >sepal length (cm)</th>
#       <th id="T_e521d_level0_col1" class="col_heading level0 col1" >sepal width (cm)</th>
#       <th id="T_e521d_level0_col2" class="col_heading level0 col2" >petal length (cm)</th>
#       <th id="T_e521d_level0_col3" class="col_heading level0 col3" >petal width (cm)</th>
#       <th id="T_e521d_level0_col4" class="col_heading level0 col4" >avg_wd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e521d_level0_row0" class="row_heading level0 row0" >GAN 2 NV 16</th>
#       <td id="T_e521d_row0_col0" class="data row0 col0" >0.118965</td>
#       <td id="T_e521d_row0_col1" class="data row0 col1" >0.069324</td>
#       <td id="T_e521d_row0_col2" class="data row0 col2" >0.261644</td>
#       <td id="T_e521d_row0_col3" class="data row0 col3" >0.105965</td>
#       <td id="T_e521d_row0_col4" class="data row0 col4" >0.138974</td>
#     </tr>
#     <tr>
#       <th id="T_e521d_level0_row1" class="row_heading level0 row1" >GAN 2 NV 64</th>
#       <td id="T_e521d_row1_col0" class="data row1 col0" >0.160924</td>
#       <td id="T_e521d_row1_col1" class="data row1 col1" >0.132034</td>
#       <td id="T_e521d_row1_col2" class="data row1 col2" >0.181203</td>
#       <td id="T_e521d_row1_col3" class="data row1 col3" >0.123224</td>
#       <td id="T_e521d_row1_col4" class="data row1 col4" >0.149347</td>
#     </tr>
#     <tr>
#       <th id="T_e521d_level0_row2" class="row_heading level0 row2" >GAN 2 NV 4</th>
#       <td id="T_e521d_row2_col0" class="data row2 col0" >0.075668</td>
#       <td id="T_e521d_row2_col1" class="data row2 col1" >0.126776</td>
#       <td id="T_e521d_row2_col2" class="data row2 col2" >0.328192</td>
#       <td id="T_e521d_row2_col3" class="data row2 col3" >0.077650</td>
#       <td id="T_e521d_row2_col4" class="data row2 col4" >0.152072</td>
#     </tr>
#     <tr>
#       <th id="T_e521d_level0_row3" class="row_heading level0 row3" >GAN 3 NV 16</th>
#       <td id="T_e521d_row3_col0" class="data row3 col0" >0.129224</td>
#       <td id="T_e521d_row3_col1" class="data row3 col1" >0.093377</td>
#       <td id="T_e521d_row3_col2" class="data row3 col2" >0.276227</td>
#       <td id="T_e521d_row3_col3" class="data row3 col3" >0.1

# %% [markdown]
# The final match is between the best model considering the KS test, a big GAN with a noise vector of 16, and the best according to the wasserstein distance, a medium GAN with a noise vector of 16.
# Considering that the performance of all three architectures with a vector of size 16 reaches an acceptable threshold, we can conclude that this is the optimal size of the noise vector.
#
# By examining the Q-Q plots we will see which architecture produces the best results.

# %%
gan2_16nv_df = pd.DataFrame(med_gan_dict['Dataframes'][3])
gan2_16nv_df['target'] = y
gan2_16nv_df['target'] = gan2_16nv_df['target'].map({i: species[i] for i in range(len(species))})
gan2_16nv_df.columns = real_iris.columns

gan3_16nv_df = pd.DataFrame(big_gan_dict['Dataframes'][3])
gan3_16nv_df['target'] = y
gan3_16nv_df['target'] = gan3_16nv_df['target'].map({i: species[i] for i in range(len(species))})
gan3_16nv_df.columns = real_iris.columns

for dataframe in [gan2_16nv_df, gan3_16nv_df]:
    utils.plot_quantiles(real_iris, dataframe)

# %%
utils.plot_data(real_iris, 'target', gan2_16nv_df)

# %%
utils.plot_data(real_iris, 'target', gan3_16nv_df)

# %% [markdown]
# Let's check the absolute mean differences between the correlations.

# %%
print(f"Medium GAN: {((real_iris.select_dtypes('number').corr() - gan2_16nv_df.select_dtypes('number').corr()).abs().mean().mean()):.4f}")
print(f"Big GAN: {((real_iris.select_dtypes('number').corr() - gan3_16nv_df.select_dtypes('number').corr()).abs().mean().mean()):.4f}")
# Out:
# Medium GAN: 0.0788
# Big GAN: 0.0682

# %%
print('Medium GAN avg correlation differences:\n')
for target in real_iris['target'].unique():
    print(f"{target.capitalize()}: {((real_iris[real_iris['target'] == target].select_dtypes('number').corr() - gan2_16nv_df[gan2_16nv_df['target'] == target].select_dtypes('number').corr()).abs().mean().mean()):.4f}")
print('\nBig GAN correlation differences:\n')
for target in real_iris['target'].unique():
    print(f"{target.capitalize()}: {((real_iris[real_iris['target'] == target].select_dtypes('number').corr() - gan3_16nv_df[gan3_16nv_df['target'] == target].select_dtypes('number').corr()).abs().mean().mean()):.4f}")
# Out:
# Medium GAN avg correlation differences:
#
# Setosa: 0.1294
# Versicolor: 0.1593
# Virginica: 0.2694
#
# Big GAN correlation differences:
#
# Setosa: 0.4591
# Versicolor: 0.4322
# Virginica: 0.2571

# %% [markdown]
# Analyzing the performance of both models with statistical and graphical methods, they seem to show rather similar performance overall. Analyzing the average differences between the class-specific correlations, the medium-size architecture shows a greater ability to reproduce 2 out of 3 classes. For this the **medium architecture with a noise vector of size 16** will be chosen.

# %% [markdown]
# ## Introducing the WGAN

# %% [markdown]
# Although in general the model can reproduce the distributions, as shown by the Q-Q plots and the mean differences between the correlations, a simple GAN does not seem enough to capture the characteristics of the specific classes.
#
# The problem must be addressed by another method: the **Wasserstein GAN**.
#
# This type of architecture exploits the Wasserstein distance, a metric that calculates the minimum transport cost of transforming one (synthetic) distribution into another (real) one, as a loss function. In addition, the **(critic)** discriminator uses an output layer devoid of the sigmoid function typical of a binary classifier, directly estimating the distance between the two distributions. These features offer several advantages, including:
# 1. Increased stability during training
# 2. Improved quality of the generated samples
#
# We will start with a relatively simple 'architecture where the noise vector of size 16 will be expanded to a size of 32.

# %%
noise_dim = 16
hidden_dim = 32
data_dim = real_iris.select_dtypes('number').shape[1]

class WGenerator(nn.Module):
    def __init__(self, noise_dim, hidden_dim, class_dim, output_dim):
        super(WGenerator, self).__init__()
        
        self.model = nn.Sequential(
            nn.Linear(noise_dim + class_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim), 
        )
    
    def forward(self, noise, labels):
        labels = labels.unsqueeze(1)
        x = torch.cat([noise, labels], dim=1)
        return self.model(x)
    
class WCritic(nn.Module):
    def __init__(self, data_dim, hidden_dim, class_dim):
        super(WCritic, self).__init__()
        
        self.model = nn.Sequential(
            nn.Linear(data_dim + class_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1),   
        )
    
    def forward(self, data, labels):
        labels = labels.unsqueeze(1)
        x = torch.cat([data, labels], dim=1)
        return self.model(x)

utils.set_seed()
gen = WGenerator(noise_dim = noise_dim, hidden_dim = hidden_dim, class_dim = 1, output_dim = data_dim)
crit = WCritic(data_dim = data_dim, hidden_dim = hidden_dim, class_dim = 1)

print(f'Generator output shape:{gen(torch.randn(32,noise_dim), batch[1]).shape}')
print(f'Critic output shape:{crit(batch[0], batch[1]).shape}')
print(f'Generator params: {sum(p.numel() for p in gen.parameters())/1000}k')
print(f'Critic params: {sum(p.numel() for p in crit.parameters())/1000}k')
# Out:
# Generator output shape:torch.Size([32, 4])
# Critic output shape:torch.Size([32, 1])
# Generator params: 1.764k
# Critic params: 1.281k

# %% [markdown]
# Perfect! The next step is to set the model losses. Specifically for the critic we will create the function for the gradient penalty so that the Wasserstein distance can be used as the loss function.
# 1. **`gradient_penalty`**:
#    - It calculates the gradient penalty for the critic, which helps meet the Lipschitz condition. This is done by interpolating between the real and fake data, calculating the critic's gradient on these data, and penalizing the difference from norm 1.
#
# 2. **`critic_loss`**:
#    - Calculate the critic's loss as the difference between the score on the fake data and the score on the real data. To this loss is added the gradient penalty to guarantee the Lipschitz condition.
#
# 3. **`generator_loss`**:
#    - It calculates the loss for the generator, which tries to fool the critic. The goal is to minimize the score the critic gives to the fake data, so the loss is the negative of this score.

# %%
def gradient_penalty(critic, real_data, fake_data, labels, lambda_gp = 10):
    batch_size = real_data.size(0)
    epsilon = torch.rand(batch_size, 1)
    epsilon = epsilon.expand_as(real_data)
    interpolated = epsilon * real_data + (1 - epsilon) * fake_data
    interpolated.requires_grad_(True)
    
    interpolated_score = critic(interpolated, labels)
    
    grad_outputs = torch.ones_like(interpolated_score)
    gradients = torch.autograd.grad(
        outputs=interpolated_score,
        inputs=interpolated,
        grad_outputs = grad_outputs,
        create_graph = True,
        retain_graph = True,
        only_inputs = True
    )[0]
    
    gradients_norm = gradients.view(batch_size, -1).norm(2, dim=1)
    penalty = lambda_gp * ((gradients_norm - 1) ** 2).mean()
    return penalty

def critic_loss(critic, real_data, fake_data, labels, lambda_gp=10):
    real_score = critic(real_data, labels)
    fake_score = critic(fake_data, labels)
    
    wasserstein_loss = fake_score.mean() - real_score.mean()
    
    gp = gradient_penalty(critic, real_data, fake_data, labels, lambda_gp)
    return wasserstein_loss + gp

def generator_loss(critic, fake_data, labels):
    fake_score = critic(fake_data, labels)
    return -fake_score.mean()

# %%
g_lr = 5e-4
c_lr = 2e-3

g_opt = torch.optim.AdamW(gen.parameters(), lr = g_lr, betas = (0.5, 0.999), weight_decay=0)
c_opt = torch.optim.RMSprop(crit.parameters(), lr = c_lr, weight_decay=0)

utils.set_seed()
z = torch.randn(150, noise_dim)

# %% [markdown]
# - **AdamW for the generator**: AdamW is chosen for the generator because of its ability to adapt dynamically to gradients and its improved handling of weight decay, which provides stability during training. The combination of **betas = (0.5, 0.999)** is particularly useful to avoid oscillations in gradients.
#
# - **RMSprop for the critic**: RMSprop is chosen for its ability to handle variable gradients in a stable manner, improving the effectiveness of the critic in calculating the Wasserstein value.
#
# Is all set, you can move on to WGAN training.

# %%
epochs = 5000
verbose = 0.1

for epoch in tqdm(range(epochs + 1)):
    
    gen.train()
    crit.train()
    
    gen_epoch_loss = 0
    crit_epoch_loss = 0
    
    for data, labels in real_gan_dataloader:
        noise = torch.randn(data.shape[0], noise_dim)
        fake_data = gen(noise, labels)
        
        c_opt.zero_grad()
        crit_loss = critic_loss(crit, data, fake_data, labels)
        crit_epoch_loss += crit_loss.item()
        crit_loss.backward()
        c_opt.step()
        
    if epoch % 5 == 0:
            
        noise = torch.randn(data.shape[0], noise_dim)
        fake_data = gen(noise, labels)
        
        g_opt.zero_grad()
        gen_loss = generator_loss(critic = crit, fake_data = fake_data, labels = labels)
        gen_epoch_loss += gen_loss.item()
        gen_loss.backward()
        g_opt.step()
        
    g_epoch_loss = gen_epoch_loss/len(real_gan_dataloader)
    c_epoch_loss = crit_epoch_loss/len(real_gan_dataloader)
    
    if epoch % (epochs * 0.1) == 0 or epoch == epochs:    
        print(f"Epoch{epoch}/{epochs} | CLoss: {c_epoch_loss:.4f} | GLoss: {g_epoch_loss:.4f}")
# Out:
#   0%|          | 0/5001 [00:00<?, ?it/s]
# Epoch0/5000 | CLoss: 5.4075 | GLoss: 0.0400
# Epoch500/5000 | CLoss: -1.4985 | GLoss: -0.0887
# Epoch1000/5000 | CLoss: -0.9109 | GLoss: -0.4761
# Epoch1500/5000 | CLoss: -0.6052 | GLoss: -0.4786
# Epoch2000/5000 | CLoss: -0.5106 | GLoss: -0.2134
# Epoch2500/5000 | CLoss: -0.3763 | GLoss: -0.4719
# Epoch3000/5000 | CLoss: -0.3018 | GLoss: -0.3703
# Epoch3500/5000 | CLoss: -0.3201 | GLoss: -0.4390
# Epoch4000/5000 | CLoss: -0.1558 | GLoss: -0.5026
# Epoch4500/5000 | CLoss: -0.1099 | GLoss: -0.3957
# Epoch5000/5000 | CLoss: -0.0727 | GLoss: -0.4021

# %% [markdown]
# Let's check the KS test and the Wasserstein distance.

# %%
fake_df = pd.DataFrame(std_scl.inverse_transform(gen(z, real_gan_dataloader.dataset.label).detach().numpy()))
fake_df['target'] = real_iris['target']
fake_df.columns = real_iris.columns
utils.calculate_ks_test(real_iris, fake_df).style.background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_175bc_row0_col1, #T_175bc_row2_col2, #T_175bc_row3_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_175bc_row0_col2, #T_175bc_row2_col1, #T_175bc_row3_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_175bc_row1_col1 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_175bc_row1_col2 {
#   background-color: #fedecf;
#   color: #000000;
# }
# </style>
# <table id="T_175bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_175bc_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_175bc_level0_col1" class="col_heading level0 col1" >KS Statistic</th>
#       <th id="T_175bc_level0_col2" class="col_heading level0 col2" >P-Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_175bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_175bc_row0_col0" class="data row0 col0" >sepal length (cm)</td>
#       <td id="T_175bc_row0_col1" class="data row0 col1" >0.073333</td>
#       <td id="T_175bc_row0_col2" class="data row0 col2" >0.816483</td>
#     </tr>
#     <tr>
#       <th id="T_175bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_175bc_row1_col0" class="data row1 col0" >sepal width (cm)</td>
#       <td id="T_175bc_row1_col1" class="data row1 col1" >0.106667</td>
#       <td id="T_175bc_row1_col2" class="data row1 col2" >0.361727</td>
#     </tr>
#     <tr>
#       <th id="T_175bc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_175bc_row2_col0" class="data row2 col0" >petal length (cm)</td>
#       <td id="T_175bc_row2_col1" class="data row2 col1" >0.113333</td>
#       <td id="T_175bc_row2_col2" class="data row2 col2" >0.291074</td>
#     </tr>
#     <tr>
#       <th id="T_175bc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_175bc_row3_col0" class="data row3 col0" >petal width (cm)</td>
#       <td id="T_175bc_row3_col1" class="data row3 col1" >0.113333</td>
#       <td id="T_175bc_row3_col2" class="data row3 col2" >0.291074</td>
#     </tr>
#   </tbody>
# </table>

# %%
utils.calculate_wasserstein_distance(real_iris, fake_df).style.background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_cda71_row0_col1 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_cda71_row1_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_cda71_row2_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_cda71_row3_col1 {
#   background-color: #ffece3;
#   color: #000000;
# }
# </style>
# <table id="T_cda71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cda71_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_cda71_level0_col1" class="col_heading level0 col1" >W Distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cda71_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cda71_row0_col0" class="data row0 col0" >sepal length (cm)</td>
#       <td id="T_cda71_row0_col1" class="data row0 col1" >0.087423</td>
#     </tr>
#     <tr>
#       <th id="T_cda71_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cda71_row1_col0" class="data row1 col0" >sepal width (cm)</td>
#       <td id="T_cda71_row1_col1" class="data row1 col1" >0.053096</td>
#     </tr>
#     <tr>
#       <th id="T_cda71_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cda71_row2_col0" class="data row2 col0" >petal length (cm)</td>
#       <td id="T_cda71_row2_col1" class="data row2 col1" >0.139005</td>
#     </tr>
#     <tr>
#       <th id="T_cda71_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cda71_row3_col0" class="data row3 col0" >petal width (cm)</td>
#       <td id="T_cda71_row3_col1" class="data row3 col1" >0.057840</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's do a graphic check.

# %%
utils.plot_quantiles(real_iris, fake_df)

# %%
utils.plot_data(real_iris, 'target', fake_df)

# %% [markdown]
# There is a significant increase in performance. Let's see how much the ability to capture the relationships between variables has improved, both overall and for each class.

# %%
print(f"Avg corr diff: {((real_iris.select_dtypes('number').corr() - fake_df.select_dtypes('number').corr()).abs().mean().mean()):.4f}\n")

print('WGAN avg correlation differences:')
for target in real_iris['target'].unique():
    print(f"{target.capitalize()}: {((real_iris[real_iris['target'] == target].select_dtypes('number').corr() - fake_df[fake_df['target'] == target].select_dtypes('number').corr()).abs().mean().mean()):.4f}")
# Out:
# Avg corr diff: 0.0235
#
# WGAN avg correlation differences:
# Setosa: 0.1621
# Versicolor: 0.0894
# Virginica: 0.0838

# %% [markdown]
# Great! The results are amazing! (Yes ok, the dataset is simple 🥲)
#
# Nevertheless we can aim higher and achieve even greater overlap. We can make up for the simplicity of the dataset by adding us complexity to our data, **creating in the new features to help the model capture other features and relationships.**
#
# Taking advantage of Samy Baladram's work we will create some features of his [Iris Extended Dataset](https://www.kaggle.com/datasets/samybaladram/iris-dataset-extended) we will gradually add some of the variables, specifically:
# $$ \text{Sepal Area} \rightarrow \text{Sepal Length} \times \text{Sepal Width} $$
#
# $$ \text{Petal Area} \rightarrow \text{Petal Length} \times \text{Petal Width} $$

# %%
aug_iris = real_iris.copy()

aug_iris['sepal area'] = aug_iris['sepal length (cm)'] * aug_iris['sepal width (cm)']
aug_iris['petal area'] = aug_iris['petal length (cm)'] * aug_iris['petal width (cm)']

target_column = aug_iris.pop('target')
aug_iris['target'] = target_column
aug_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    sepal area  petal area  target
# 0       17.85        0.28  setosa
# 1       14.70        0.28  setosa
# 2       15.04        0.26  setosa
# 3       14.26        0.30  setosa
# 4       18.00        0.28  setosa

# %%
X_aug, y = aug_iris.select_dtypes('number'), y

aug_std_scl = StandardScaler()
X_aug_scld = aug_std_scl.fit_transform(X_aug)

aug_gan_dataset = IrisDataset(X_aug_scld, y)
aug_gan_dataloader = DataLoader(aug_gan_dataset, batch_size = 32, shuffle= True)

for batch in aug_gan_dataloader:
    gan_batch = batch
    break
    
print(gan_batch[0].shape)
print(gan_batch[1].shape)
# Out:
# torch.Size([32, 6])
# torch.Size([32])

# %%
data_dim = aug_iris.shape[1] - 1

utils.set_seed()
gen = WGenerator(noise_dim = noise_dim, output_dim = data_dim, hidden_dim = 32, class_dim = 1)
crit = WCritic(data_dim = data_dim, hidden_dim = 32, class_dim = 1)

batch_size = 32
noise = torch.randn(batch_size, noise_dim)
labels = torch.randint(0, 2, (batch_size,))

print(gen(noise, labels).shape)

print(crit(torch.randn(32, data_dim), batch[1]).shape)
# Out:
# torch.Size([32, 6])
# torch.Size([32, 1])

# %%
g_lr = 5e-4
c_lr = 2e-3

g_opt = torch.optim.AdamW(gen.parameters(), lr = g_lr, betas = (0.5, 0.999), weight_decay=0)
c_opt = torch.optim.RMSprop(crit.parameters(), lr = c_lr, weight_decay=0)

utils.set_seed()
z = torch.randn(150, noise_dim)

# %% [markdown]
# We will train models for a large number of epochs **(30k)** to ensure the generator has more time and opportunities to improve than the critic.

# %%
epochs = 30000
verbose = 0.1

crit_loss_list = []
gen_loss_list = []

for epoch in tqdm(range(epochs + 1)):
    
    gen.train()
    crit.train()
    
    gen_epoch_loss = 0
    crit_epoch_loss = 0
    
    for data, labels in aug_gan_dataloader:
        noise = torch.randn(data.shape[0], noise_dim)
        fake_data = gen(noise, labels)
        
        c_opt.zero_grad()
        crit_loss = critic_loss(crit, data, fake_data, labels)
        crit_epoch_loss += crit_loss.item()
        crit_loss.backward()
        c_opt.step()
        
    if epoch % 5 == 0:
            
        noise = torch.randn(data.shape[0], noise_dim)
        fake_data = gen(noise, labels)
        
        g_opt.zero_grad()
        gen_loss = generator_loss(critic = crit, fake_data = fake_data, labels = labels)
        gen_epoch_loss += gen_loss.item()
        gen_loss.backward()
        g_opt.step()
        
    g_epoch_loss = gen_epoch_loss/len(aug_gan_dataloader)
    c_epoch_loss = crit_epoch_loss/len(aug_gan_dataloader)
    
    if epoch % (epochs * 0.1) == 0 or epoch == epochs:    
        print(f"Epoch{epoch}/{epochs} | CLoss: {c_epoch_loss:.4f} | GLoss: {g_epoch_loss:.4f}")
# Out:
#   0%|          | 0/30001 [00:00<?, ?it/s]
# Epoch0/30000 | CLoss: 4.2877 | GLoss: 0.1428
# Epoch3000/30000 | CLoss: -0.3507 | GLoss: -1.1359
# Epoch6000/30000 | CLoss: -0.0927 | GLoss: -1.0770
# Epoch9000/30000 | CLoss: -0.1033 | GLoss: -0.8665
# Epoch12000/30000 | CLoss: -0.0591 | GLoss: -0.4706
# Epoch15000/30000 | CLoss: -0.0472 | GLoss: -0.4091
# Epoch18000/30000 | CLoss: -0.1136 | GLoss: -0.2932
# Epoch21000/30000 | CLoss: -0.1210 | GLoss: -0.4596
# Epoch24000/30000 | CLoss: -0.1010 | GLoss: -0.5386
# Epoch27000/30000 | CLoss: -0.1030 | GLoss: -0.3717
# Epoch30000/30000 | CLoss: -0.1002 | GLoss: -0.4752

# %%
fake_df = pd.DataFrame(aug_std_scl.inverse_transform(gen(z, aug_gan_dataloader.dataset.label).detach().numpy()))
fake_df['target'] = aug_iris['target']
fake_df.columns = aug_iris.columns
fake_df = fake_df[real_iris.columns]
utils.calculate_ks_test(real_iris, fake_df).style.background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_8d079_row0_col1, #T_8d079_row1_col2, #T_8d079_row2_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_8d079_row0_col2, #T_8d079_row1_col1, #T_8d079_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_8d079_row3_col1 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_8d079_row3_col2 {
#   background-color: #feeae1;
#   color: #000000;
# }
# </style>
# <table id="T_8d079">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d079_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_8d079_level0_col1" class="col_heading level0 col1" >KS Statistic</th>
#       <th id="T_8d079_level0_col2" class="col_heading level0 col2" >P-Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d079_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d079_row0_col0" class="data row0 col0" >sepal length (cm)</td>
#       <td id="T_8d079_row0_col1" class="data row0 col1" >0.060000</td>
#       <td id="T_8d079_row0_col2" class="data row0 col2" >0.951111</td>
#     </tr>
#     <tr>
#       <th id="T_8d079_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d079_row1_col0" class="data row1 col0" >sepal width (cm)</td>
#       <td id="T_8d079_row1_col1" class="data row1 col1" >0.126667</td>
#       <td id="T_8d079_row1_col2" class="data row1 col2" >0.180395</td>
#     </tr>
#     <tr>
#       <th id="T_8d079_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d079_row2_col0" class="data row2 col0" >petal length (cm)</td>
#       <td id="T_8d079_row2_col1" class="data row2 col1" >0.060000</td>
#       <td id="T_8d079_row2_col2" class="data row2 col2" >0.951111</td>
#     </tr>
#     <tr>
#       <th id="T_8d079_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d079_row3_col0" class="data row3 col0" >petal width (cm)</td>
#       <td id="T_8d079_row3_col1" class="data row3 col1" >0.120000</td>
#       <td id="T_8d079_row3_col2" class="data row3 col2" >0.230782</td>
#     </tr>
#   </tbody>
# </table>

# %%
utils.calculate_wasserstein_distance(real_iris, fake_df).style.background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_4a98b_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_4a98b_row1_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_4a98b_row2_col1 {
#   background-color: #920a13;
#   color: #f1f1f1;
# }
# #T_4a98b_row3_col1 {
#   background-color: #af1117;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4a98b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a98b_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_4a98b_level0_col1" class="col_heading level0 col1" >W Distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a98b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a98b_row0_col0" class="data row0 col0" >sepal length (cm)</td>
#       <td id="T_4a98b_row0_col1" class="data row0 col1" >0.064483</td>
#     </tr>
#     <tr>
#       <th id="T_4a98b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a98b_row1_col0" class="data row1 col0" >sepal width (cm)</td>
#       <td id="T_4a98b_row1_col1" class="data row1 col1" >0.042666</td>
#     </tr>
#     <tr>
#       <th id="T_4a98b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a98b_row2_col0" class="data row2 col0" >petal length (cm)</td>
#       <td id="T_4a98b_row2_col1" class="data row2 col1" >0.062556</td>
#     </tr>
#     <tr>
#       <th id="T_4a98b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a98b_row3_col0" class="data row3 col0" >petal width (cm)</td>
#       <td id="T_4a98b_row3_col1" class="data row3 col1" >0.061056</td>
#     </tr>
#   </tbody>
# </table>

# %%
utils.plot_quantiles(real_iris, fake_df)

# %%
utils.plot_data(real_iris, 'target', fake_df)

# %%
print(f"Avg corr diff: {((real_iris.select_dtypes('number').corr() - fake_df.select_dtypes('number').corr()).abs().mean().mean()):.4f}\n")

print('WGAN avg correlation differences:')
for target in real_iris['target'].unique():
    print(f"{target.capitalize()}: {((real_iris[real_iris['target'] == target].select_dtypes('number').corr() - fake_df[fake_df['target'] == target].select_dtypes('number').corr()).abs().mean().mean()):.4f}")
# Out:
# Avg corr diff: 0.0031
#
# WGAN avg correlation differences:
# Setosa: 0.0959
# Versicolor: 0.0448
# Virginica: 0.0408

# %% [markdown]
# Perfect! The performance is optimal:
# 1. In all **Kolmogorov-Smirnov's tests** we cannot reject the null hypothesis that the data, real and synthetic, come from two different distributions.
# 2. All **Wasserstein distances** are small (< 0.1).
# 3. From the **Q-Q and distributions plots** we see a very good overlap.
# 4. All the **mean absolute differences between correleations** are small (< 0.1)

# %%
utils.describe_data(real_iris, 'target', fake_df).style.background_gradient('viridis', axis = 1)
# Out:
# <style type="text/css">
# #T_695e5_row0_col0, #T_695e5_row14_col3, #T_695e5_row22_col4 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_695e5_row0_col1 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_695e5_row0_col2, #T_695e5_row0_col5, #T_695e5_row1_col3, #T_695e5_row2_col2, #T_695e5_row3_col5, #T_695e5_row4_col2, #T_695e5_row5_col3, #T_695e5_row6_col2, #T_695e5_row7_col2, #T_695e5_row8_col5, #T_695e5_row9_col3, #T_695e5_row10_col5, #T_695e5_row11_col5, #T_695e5_row12_col2, #T_695e5_row13_col3, #T_695e5_row14_col2, #T_695e5_row15_col5, #T_695e5_row16_col4, #T_695e5_row17_col3, #T_695e5_row18_col2, #T_695e5_row19_col0, #T_695e5_row20_col5, #T_695e5_row21_col0, #T_695e5_row22_col3, #T_695e5_row23_col0, #T_695e5_row24_col1, #T_695e5_row24_col5, #T_695e5_row25_col3, #T_695e5_row26_col5, #T_695e5_row27_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_695e5_row0_col3, #T_695e5_row1_col1, #T_695e5_row1_col4, #T_695e5_row2_col0, #T_695e5_row2_col3, #T_695e5_row3_col3, #T_695e5_row4_col0, #T_695e5_row5_col5, #T_695e5_row6_col0, #T_695e5_row7_col0, #T_695e5_row8_col3, #T_695e5_row9_col1, #T_695e5_row10_col3, #T_695e5_row11_col3, #T_695e5_row12_col0, #T_695e5_row13_col4, #T_695e5_row14_col0, #T_695e5_row15_col3, #T_695e5_row16_col5, #T_695e5_row17_col4, #T_695e5_row18_col1, #T_695e5_row19_col3, #T_695e5_row20_col1, #T_695e5_row21_col4, #T_695e5_row22_col5, #T_695e5_row23_col2, #T_695e5_row24_col0, #T_695e5_row25_col2, #T_695e5_row26_col0, #T_695e5_row27_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_695e5_row0_col4 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_695e5_row1_col0 {
#   background-color: #fbe723;
#   color: #000000;
# }
# #T_695e5_row1_col2 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_695e5_row1_col5, #T_695e5_row5_col2, #T_695e5_row19_col5 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_695e5_row2_col1 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_695e5_row2_col4, #T_695e5_row11_col4 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# #T_695e5_row2_col5 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_695e5_row3_col0 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_695e5_row3_col1, #T_695e5_row4_col1 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_695e5_row3_col2 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_695e5_row3_col4 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_695e5_row4_col3 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_695e5_row4_col4 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_695e5_row4_col5 {
#   background-color: #a5db36;
#   color: #000000;
# }
# #T_695e5_row5_col0 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_695e5_row5_col1 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_695e5_row5_col4 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_695e5_row6_col1 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_695e5_row6_col3, #T_695e5_row21_col1 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_695e5_row6_col4 {
#   background-color: #8bd646;
#   color: #000000;
# }
# #T_695e5_row6_col5 {
#   background-color: #b2dd2d;
#   color: #000000;
# }
# #T_695e5_row7_col1 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_695e5_row7_col3 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_695e5_row7_col4 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_695e5_row7_col5 {
#   background-color: #dfe318;
#   color: #000000;
# }
# #T_695e5_row8_col0 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_695e5_row8_col1, #T_695e5_row8_col2, #T_695e5_row21_col2 {
#   background-color: #95d840;
#   color: #000000;
# }
# #T_695e5_row8_col4 {
#   background-color: #cae11f;
#   color: #000000;
# }
# #T_695e5_row9_col0 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_695e5_row9_col2, #T_695e5_row22_col1, #T_695e5_row24_col4 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_695e5_row9_col4, #T_695e5_row23_col1 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_695e5_row9_col5 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_695e5_row10_col0 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_695e5_row10_col1 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_695e5_row10_col2 {
#   background-color: #dde318;
#   color: #000000;
# }
# #T_695e5_row10_col4 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_695e5_row11_col0 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_695e5_row11_col1, #T_695e5_row16_col1, #T_695e5_row17_col2, #T_695e5_row25_col0, #T_695e5_row25_col1 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_695e5_row11_col2 {
#   background-color: #c2df23;
#   color: #000000;
# }
# #T_695e5_row12_col1, #T_695e5_row12_col4, #T_695e5_row15_col1 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_695e5_row12_col3, #T_695e5_row16_col3 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_695e5_row12_col5, #T_695e5_row14_col5 {
#   background-color: #f4e61e;
#   color: #000000;
# }
# #T_695e5_row13_col0 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_695e5_row13_col1, #T_695e5_row26_col3 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_695e5_row13_col2 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_695e5_row13_col5 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_695e5_row14_col1, #T_695e5_row26_col1 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_695e5_row14_col4 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_695e5_row15_col0 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_695e5_row15_col2 {
#   background-color: #b5de2b;
#   color: #000000;
# }
# #T_695e5_row15_col4 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_695e5_row16_col0 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_695e5_row16_col2, #T_695e5_row25_col4, #T_695e5_row26_col4 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_695e5_row17_col0 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_695e5_row17_col1 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_695e5_row17_col5 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_695e5_row18_col0 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_695e5_row18_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_695e5_row18_col4 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_695e5_row18_col5 {
#   background-color: #bade28;
#   color: #000000;
# }
# #T_695e5_row19_col1 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_695e5_row19_col2 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_695e5_row19_col4 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_695e5_row20_col0 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_695e5_row20_col2 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_695e5_row20_col3, #T_695e5_row22_col2 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_695e5_row20_col4 {
#   background-color: #b0dd2f;
#   color: #000000;
# }
# #T_695e5_row21_col3 {
#   background-color: #c5e021;
#   color: #000000;
# }
# #T_695e5_row21_col5 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_695e5_row22_col0, #T_695e5_row26_col2 {
#   background-color: #c0df25;
#   color: #000000;
# }
# #T_695e5_row23_col3 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_695e5_row23_col4, #T_695e5_row27_col3 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_695e5_row23_col5 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_695e5_row24_col2 {
#   background-color: #c8e020;
#   color: #000000;
# }
# #T_695e5_row24_col3, #T_695e5_row27_col1 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_695e5_row25_col5 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_695e5_row27_col4 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_695e5_row27_col5 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_695e5">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_695e5_level0_col0" class="col_heading level0 col0" colspan="3">REAL</th>
#       <th id="T_695e5_level0_col3" class="col_heading level0 col3" colspan="3">SYNTHETIC</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;<

# %% [markdown]
# We can now save our model parameters for further data generations.

# %%
torch.save(gen.state_dict(), "Models/WGAN_weights.pth")

# %% [markdown]
# The first phase of the project is completed. The second will be divided into two sub-step:
# 1. **Train on real Test on Synthetic**
# 2. **Train on Synthetic Test on Real**

# %% [markdown]
# ## Evaluating Synthetic Data

# %% [markdown]
# In this final stage, the quality of the synthetic data will be assessed using the **Train on Real Test on Synthetic** and **Train on Synthetic Test on Real** protocols. At the point when the performance of these two classifiers should be similar this would mean that the synthetic data are not so much distinguishable from the real data and therefore their quality will be acceptable.
#
# Let's start by generating data with our model.

# %%
utils.set_seed()
z = torch.randn(150, 16)

fake_iris = pd.DataFrame(aug_std_scl.inverse_transform(gen(z, aug_gan_dataloader.dataset.label).detach().numpy()))
fake_iris['target'] = aug_iris['target']
fake_iris.columns = aug_iris.columns
fake_iris = fake_iris[real_iris.columns]

fake_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0           5.843816          4.091078           1.408269          0.179515
# 1           5.561580          4.102568           1.162238          0.206625
# 2           5.380793          4.206643           1.624508          0.213553
# 3           5.023266          3.152396           1.477270          0.248045
# 4           5.045128          3.381160           1.486368          0.245855
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# Next is to create the Dataloader.

# %%
X_real, y_real = real_iris.select_dtypes('number'), y

X_fake, y_fake = fake_iris.select_dtypes('number'), y

X_real_train, X_real_, y_real_train, y_real_ = train_test_split(X_real, y_real, test_size = 0.2, 
                                                                stratify = y_real, random_state = 0)
X_real_val, X_real_test, y_real_val, y_real_test = train_test_split(X_real_, y_real_, test_size = 0.5, 
                                                                    stratify = y_real_, random_state = 0)

X_fake_train, X_fake_, y_fake_train, y_fake_ = train_test_split(X_fake, y_fake, test_size = 0.2, 
                                                                stratify = y_fake, random_state = 0)
X_fake_val, X_fake_test, y_fake_val, y_fake_test = train_test_split(X_fake_, y_fake_, test_size = 0.5, 
                                                                    stratify = y_fake_, random_state = 0)

real_train_dict = {'Train Set': X_real_train, 'Val Set': X_real_val, 'Test Set': X_real_test}
fake_train_dict = {'Train Set': X_fake_train, 'Val Set': X_fake_val, 'Test Set': X_fake_test}

std_scaler = StandardScaler()

for dataset in [real_train_dict, fake_train_dict]:
    
    dataset['Train Set'] = std_scaler.fit_transform(dataset['Train Set'])
    dataset['Val Set'] = std_scaler.transform(dataset['Val Set'])
    dataset['Test Set'] = std_scaler.transform(dataset['Test Set'])
    
X_real_train, X_real_val, X_real_test = real_train_dict['Train Set'], real_train_dict['Val Set'], real_train_dict['Test Set']
X_fake_train, X_fake_val, X_fake_test = fake_train_dict['Train Set'], fake_train_dict['Val Set'], fake_train_dict['Test Set']

print(f'Train instances: {X_real_train.shape[0]}')
print(f'Val instances: {X_real_val.shape[0]}')
print(f'Test instances: {X_real_test.shape[0]}')
# Out:
# Train instances: 120
# Val instances: 15
# Test instances: 15

# %%
real_train_dataset = IrisDataset(X_real_train, y_real_train)
real_val_dataset = IrisDataset(X_real_val, y_real_val)
real_test_dataset = IrisDataset(X_real_test, y_real_test)

real_train_dataloader = DataLoader(real_train_dataset, batch_size = 32, shuffle = True)

fake_train_dataset = IrisDataset(X_fake_train, y_fake_train)
fake_val_dataset = IrisDataset(X_fake_val, y_fake_val)
fake_test_dataset = IrisDataset(X_fake_test, y_fake_test)

fake_train_dataloader = DataLoader(fake_train_dataset, batch_size = 32, shuffle = True)

# %% [markdown]
# Perfect! Now let's build a simple classifier.

# %%
data_dim = real_iris.select_dtypes('number').shape[1]
target_dim = real_iris['target'].nunique()

class Classifier(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        
        self.Classifier = nn.Sequential(
            nn.Linear(input_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, output_dim)
        )
        
    def forward(self, x):
        x = self.Classifier(x)
        return x    

utils.set_seed()
TOR_clf = Classifier(input_dim = data_dim, output_dim = target_dim)
TOS_clf = Classifier(input_dim = data_dim, output_dim = target_dim)

print(f'Classifier has {sum(p.numel() for p in TOR_clf.parameters())} parameters.')
# Out:
# Classifier has 739 parameters.

# %% [markdown]
# Now we proceed with the training cycle.

# %%
clf_lr = 1e-3

TOR_opt = torch.optim.AdamW(TOR_clf.parameters(), lr = clf_lr)
TOS_opt = torch.optim.AdamW(TOS_clf.parameters(), lr = clf_lr)

criterion = nn.CrossEntropyLoss()

TOR_dict = {'Model': TOR_clf, 'Dataloader': real_train_dataloader, 'Validation': real_val_dataset, 
            'Optimizer': TOR_opt, 'Train Loss': [], 'Val Loss':[], 'Label':'Real'}

TOS_dict = {'Model': TOS_clf, 'Dataloader': fake_train_dataloader, 'Validation': fake_val_dataset, 
            'Optimizer': TOS_opt, 'Train Loss': [], 'Val Loss':[], 'Label':'Synthetic'}

# %%
epochs = 150

for clf in [TOR_dict, TOS_dict]:
    for epoch in tqdm(range(epochs + 1), desc = f"Training on {clf['Label']} Data"):
        
        clf['Model'].train()
        
        epoch_loss = 0
        
        for batch, (data, label) in enumerate(clf['Dataloader']):
            
            clf['Optimizer'].zero_grad()
            
            y_pred_logits = clf['Model'](data)
            loss = criterion(y_pred_logits, label)
            epoch_loss += loss.item()
            
            loss.backward()
            clf['Optimizer'].step()
            
        with torch.no_grad():
            clf['Model'].eval()
            y_val_logits = clf['Model'](clf['Validation'].data)
            clf['Val Loss'].append(criterion(y_val_logits, clf['Validation'].label).item())
            
        clf['Train Loss'].append(epoch_loss/len(clf['Dataloader']))
        
        if epoch % 50 == 0 or epoch == epochs:
            print(f"{epoch}/{epochs} | Train loss: {clf['Train Loss'][-1]:.4f} | Val loss: {clf['Val Loss'][-1]:.4f}")
# Out:
# Training on Real Data:   0%|          | 0/151 [00:00<?, ?it/s]
# 0/150 | Train loss: 1.1093 | Val loss: 1.0946
# 50/150 | Train loss: 0.1901 | Val loss: 0.1190
# 100/150 | Train loss: 0.0809 | Val loss: 0.0523
# 150/150 | Train loss: 0.0628 | Val loss: 0.0565
# Training on Synthetic Data:   0%|          | 0/151 [00:00<?, ?it/s]
# 0/150 | Train loss: 1.0828 | Val loss: 1.0730
# 50/150 | Train loss: 0.2189 | Val loss: 0.2754
# 100/150 | Train loss: 0.0561 | Val loss: 0.1348
# 150/150 | Train loss: 0.0283 | Val loss: 0.1216

# %%
plt.figure(figsize = (16, 9))
for model in [TOR_dict, TOS_dict]:
    if model['Label'] == 'Synthetic':
        line = '--'
    else:
        line = '-'

    plt.plot(model['Train Loss'], label = f"{model['Label']} Train", linestyle = line)
    plt.plot(model['Val Loss'], label = f"{model['Label']} Val", linestyle = line)

plt.title('Training and Validation Loss', weight = 'bold', size = 20)
plt.xlabel('Epoch', weight = 'bold', size = 15)
plt.ylabel('Loss', weight = 'bold', size = 15)
plt.legend()
plt.legend()
plt.grid(True)
plt.tight_layout();

# %% [markdown]
# The loss trend of both models during training is the correct one. Moreover, both reach an optimal level of performance (as shown by both very low losses at the end of the training cycle).
#
# Its time to examine their performance.

# %% [markdown]
# The following metrics will be used:
#
# - **Accuracy** measures the proportion of correctly classified instances to the total:
#   $$
#   Accuracy = \frac{TP + TN}{TP + TN + FP + FN}
#   $$
#
# - **Precision** assesses the quality of positive predictions, indicating the proportion of actually positive instances among those classified as such:
#   $$
#   Precision = \frac{TP}{TP + FP}
#   $$
#
# - **Recall** (or Sensitivity) measures the model's ability to correctly identify positive instances, that is, the fraction of true positives out of the total number of positive instances:
#   $$
#   Recall = \frac{TP}{TP + FN}
#   $$
#
# - **F1-Score** is the harmonic mean between Precision and Recall, useful when there is a trade-off between the two metrics:
#   $$
#   F1 = \frac{2 \times Precision \times Recall}{Precision + Recall}
#   $$
#
# Where:
# - $TP$: True Positives
# - $TN$: True Negatives
# - $FP$: False Positives
# - $FN$: False Negatives

# %%
accuracy = torchmetrics.Accuracy(task = "multiclass", num_classes = target_dim)
precision = torchmetrics.Precision(task = "multiclass", num_classes = target_dim)
recall = torchmetrics.Recall(task = "multiclass", num_classes = target_dim)
f1 = torchmetrics.F1Score(task = "multiclass", num_classes = target_dim)

tor_metrics_list = []
tos_metrics_list = []

with torch.no_grad():
    TOR_dict['Model'].eval()
    y_test_pred = TOR_dict['Model'](real_test_dataset.data)
    y_test_pred_labels = torch.argmax(y_test_pred, dim = 1)

    for metric in [accuracy, precision, recall, f1]:
        metric.reset()
        tor_metrics_list.append(metric(y_test_pred_labels, real_test_dataset.label).item())

with torch.no_grad():
    TOS_dict['Model'].eval()
    y_test_pred = TOS_dict['Model'](fake_test_dataset.data)
    y_test_pred_labels = torch.argmax(y_test_pred, dim = 1)

    for metric in [accuracy, precision, recall, f1]:
        metric.reset()
        tos_metrics_list.append(metric(y_test_pred_labels, fake_test_dataset.label).item())

print(f'Real | Accuracy: {tor_metrics_list[0]:.4%} | Precision: {tor_metrics_list[1]:.4%} | Recall: {tor_metrics_list[2]:.4%} | F1: {tor_metrics_list[3]:.4%}')
print(f'Fake | Accuracy: {tos_metrics_list[0]:.4%} | Precision: {tos_metrics_list[1]:.4%} | Recall: {tos_metrics_list[2]:.4%} | F1: {tos_metrics_list[3]:.4%}')
# Out:
# Real | Accuracy: 93.3333% | Precision: 93.3333% | Recall: 93.3333% | F1: 93.3333%
# Fake | Accuracy: 100.0000% | Precision: 100.0000% | Recall: 100.0000% | F1: 100.0000%

# %%
with torch.no_grad():
    TOR_dict['Model'].eval()
    y_test_pred = TOR_dict['Model'](real_test_dataset.data)
    y_test_pred_labels = torch.argmax(y_test_pred, dim = 1)
    
    real_test_confusion_matrix = confusion_matrix(real_test_dataset.label, y_test_pred_labels, normalize = 'all')
    
with torch.no_grad():
    TOS_dict['Model'].eval()
    y_test_pred = TOR_dict['Model'](fake_test_dataset.data)
    y_test_pred_labels = torch.argmax(y_test_pred, dim = 1)
    
    fake_test_confusion_matrix = confusion_matrix(fake_test_dataset.label, y_test_pred_labels, normalize = 'all')
    
fig, ax = plt.subplots(1, 2, figsize = (16, 8))
    
for idx, data in enumerate([real_test_confusion_matrix, fake_test_confusion_matrix]):
    sns.heatmap(data = data, ax = ax[idx], cbar = False, cmap = 'viridis', annot = True, robust = True, 
                annot_kws = {'weight':'bold', 'size':20}, xticklabels = species, yticklabels = species, 
                linewidth = 0.5, fmt = '.2%')
    ax[idx].set_xlabel('Predicted', weight = 'bold', size = 15)
    ax[idx].set_ylabel('Real', weight = 'bold', size = 15)
    ax[idx].tick_params(axis='x', labelsize=15)
    ax[idx].tick_params(axis='y', labelsize=15)
    
    if idx == 0:
        title = 'Real Data: Test Set'
    else:
        title = 'Synthetic Data: Test Set'
        
    ax[idx].set_title(title, size = 20, weight = 'bold')
    
plt.tight_layout();

# %% [markdown]
# Great! The classifiers are ready. Now the key moment: Let's test each on the other's data.

# %%
full_real_scaled = np.vstack([X_real_train, X_real_val, X_real_test])
full_fake_scaled = np.vstack([X_fake_train, X_fake_val, X_fake_test])

full_target = np.hstack([y_real_train, y_real_val, y_real_test])

full_real_iris_dataset = IrisDataset(full_real_scaled, full_target)
full_fake_iris_dataset = IrisDataset(full_fake_scaled, full_target)

TOR_dict['Model'].eval()
TOR_test_on_fake = TOR_dict['Model'](full_fake_iris_dataset.data)
TOR_test_on_fake_labels = torch.argmax(TOR_test_on_fake, dim = 1)
    
TOS_dict['Model'].eval()
TOS_test_on_real = TOS_dict['Model'](full_real_iris_dataset.data)
TOS_test_on_real_labels = torch.argmax(TOS_test_on_real, dim = 1)

trained_real_test_fake_cf = confusion_matrix(full_fake_iris_dataset.label, TOR_test_on_fake_labels, normalize = 'all')
trained_fake_test_real_cf = confusion_matrix(full_real_iris_dataset.label, TOS_test_on_fake_labels, normalize = 'all')

fig, ax = plt.subplots(1, 2, figsize = (16, 8))
    
for idx, data in enumerate([trained_real_test_fake_cf, trained_fake_test_real_cf]):
    sns.heatmap(data = data, ax = ax[idx], cbar = False, cmap = 'viridis', annot = True, robust = True, 
                annot_kws = {'weight':'bold', 'size':20}, xticklabels = species, yticklabels = species, 
                linewidth = 0.5, fmt = '.2%')
    ax[idx].set_xlabel('Predicted', weight = 'bold', size = 15)
    ax[idx].set_ylabel('Real', weight = 'bold', size = 15)
    ax[idx].tick_params(axis='x', labelsize=15)
    ax[idx].tick_params(axis='y', labelsize=15)
    
    if idx == 0:
        title = 'Train on Real Test on Synthetic'
    else:
        title = 'Train on Synthetic Test on Real'
        
    ax[idx].set_title(title, size = 20, weight = 'bold')
    
plt.tight_layout();
